# %% [markdown]
# # Import

# %%
import os
import re
import gc
import sys 
from datetime import datetime
from loguru import logger

from statsmodels.nonparametric.smoothers_lowess import lowess


import torch
import numpy as np
import pyqtgraph as pg
# %gui qt



import matplotlib.pyplot as plt
# %matplotlib qt

# %% [markdown]
# # Input Layer

# %% [markdown]
# ## Definition

# %%
READ_RAW_FLAG = True

# %%
def SearchELE(rootPath, ele_pattern = re.compile(r"(.+?)_归档")):
    '''==================================================
        Search all electrode directories in the rootPath
        Parameter: 
            rootPath: current search path
            ele_pattern: electrode dir name patten
        Returen:
            ele_list: list of electrode directories
        ==================================================
    '''
    ele_list = []
    for i in os.listdir(rootPath):
        _path = os.path.join(rootPath, i)
        if os.path.isdir(_path):
            match_ele = ele_pattern.match(i)
            if match_ele:
                ele_list.append([_path, match_ele.group(1)])
            else:
                ele_list.extend(SearchELE(_path, ele_pattern))

    return ele_list



def Load_Single(ele_id, rootPath, DATA_SUFFIX):
    fd_pt = os.path.join(f"{rootPath}/{ele_id}_归档", DATA_SUFFIX, f"{ele_id}_{DATA_SUFFIX}.pt")
    if not os.path.exists(fd_pt):
        logger.warning(f"{fd_pt} does not exist")
        return None
    data_pt = torch.load(fd_pt, weights_only=False)
    _data_group = data_pt["data_group"]

    return _data_group


def DRT_Lowess(DRTdata):
    '''==================================================
        DRT Analysis with Lowess
        Parameter: 
            DRTdata:    list of tuples (tau_i, R_i, C_i) for each sample
        Returen:
            DRTdata_Loess:    Loess smoothed DRT data
        ==================================================
    '''

    # _tau_i  = np.concatenate([i[0,1:-1] for i in DRTdata])
    # _R_i    = np.concatenate([i[1,1:-1] for i in DRTdata])
    # _C_i    = np.concatenate([i[2,1:-1] for i in DRTdata])
    _tau_i  = np.concatenate([i[0,:] for i in DRTdata])
    _R_i    = np.concatenate([i[1,:] for i in DRTdata])
    _C_i    = np.concatenate([i[2,:] for i in DRTdata])

    # _order  = _tau_i.argsort()
    # _tau_i  = _tau_i[_order]
    # _R_i    = _R_i[_order]
    # _C_i    = _C_i[_order]

    x_log = np.log(_tau_i)
    y_log = np.log(_R_i)-np.log(_C_i)
    
    y_log_smooth = lowess(y_log, x_log, frac=0.1, it=3, return_sorted=False)


    R_loess         = np.exp((x_log + y_log_smooth)/2)
    tau_loess       = _tau_i
    C_loess         = _tau_i / R_loess
    DRTdata_Loess   =  np.array([tau_loess, R_loess, C_loess])

    return DRTdata_Loess

def DRT_Plot_Batch(fig, DRTdata_list, EISdata_list, Loess_list, eis_seq):
    
    axis = [0] * 6
    axis[0] = fig.add_subplot(2,3,1)    # Nyquist Plot
    axis[1] = fig.add_subplot(2,3,2)    # Bode Plot (Magnitude)
    axis[2] = fig.add_subplot(2,3,3)    # Bode Plot (Phase)
    axis[3] = fig.add_subplot(2,3,4)    # Text
    axis[4] = fig.add_subplot(2,3,5)    # DRT (RC)
    axis[5] = fig.add_subplot(2,3,6)    # DRT (Rτ)


    text_axis = axis[3]
    text_axis.axis('off')

    _s       = 2
    _alpha   = 0.7

    cmap = plt.colormaps.get_cmap('rainbow_r')
    for i in range(len(EISdata_list)):
        if i in eis_seq:
            ch_eis      = EISdata_list[i][0]
            ch_drt      = DRTdata_list[i]
            ch_loess    = Loess_list[i]

            # ch_R    = np.array([i[1:,0] for i in ch_drt])
            # ch_C    = np.array([i[1:,-1] for i in ch_drt])
            ch_R    = np.concatenate([i[1,:] for i in ch_drt])
            ch_C    = np.concatenate([i[2,:] for i in ch_drt])

            _color  = cmap(i/len(EISdata_list))

            axis[0].plot(ch_eis[1,:], -ch_eis[2,:], color = _color, linewidth=2)
            axis[1].loglog(ch_eis[0,:], np.abs(ch_eis[1,:]+1j*ch_eis[2,:]), color = _color, linewidth=2)
            axis[2].semilogx(ch_eis[0,:], np.rad2deg(np.angle(ch_eis[1,:]+1j*ch_eis[2,:])), color = _color, linewidth=2)

            axis[4].scatter(ch_R, ch_C, s=_s, alpha=_alpha, color=_color, label=f'ch[{i:03d}]')
            axis[5].scatter(ch_loess[0,:], ch_loess[1,:], s=_s, alpha=_alpha, color=_color, label=f'ch[{i:03d}]')



    axis[0].set_aspect('equal', adjustable='datalim')
    axis[4].set_xscale('log')
    axis[4].set_yscale('log')
    axis[5].set_xscale('log')
    axis[5].set_yscale('log')


    return text_axis

# %% [markdown]
# ## Archive Old - Loewner

# %% [markdown]
# ### Extract All Data

# %%
if READ_RAW_FLAG:
    rootPath = "D:/Baihm/EISNN/Archive/"
    ele_list = SearchELE(rootPath, re.compile(r"(.+?)_归档"))
    DATASET_SUFFIX = "Outlier_Ver04"


    n_ele = len(ele_list)
    logger.info(f"Search in {rootPath} and find {n_ele:03d} electrodes")
# Out:
# 2025-07-24 12:33:11.968 | INFO     | __main__:<module>:8 - Search in D:/Baihm/EISNN/Archive/ and find 218 electrodes

# %%
if READ_RAW_FLAG:
    DRT_SUFFIX = f"{DATASET_SUFFIX}_DRTLoe_Ver02"

    vitro0_start_list = []
    vitro0_start_id_list = []
    vitro0_data_list = []
    vitro0_low_list = []
    vitro0_id_list = []

    n_avaliable = 0
    n_all_channel = 0

    for i in range(n_ele):
    # for i in range(3):
        fd_pt = os.path.join(ele_list[i][0], DRT_SUFFIX, f"{ele_list[i][1]}_{DRT_SUFFIX}.pt")
        if not os.path.exists(fd_pt):
            logger.warning(f"{fd_pt} does not exist")
            continue


        data_pt = torch.load(fd_pt)
        _meta_group = data_pt["meta_group"]
        _data_group = data_pt["data_group"]


        ele_id  = _meta_group["ele_id"]
        elePath = _meta_group["elePath"]
        n_ch = _meta_group["n_ch"]      
        n_valid_ch  = len(_data_group["Channels"])

        x_day_full = _meta_group["TimeSpan"]
        _x_date = np.array([(poi - x_day_full[0]).days for poi in x_day_full])


        n_avaliable = n_avaliable + 1
        n_all_channel = n_all_channel + n_valid_ch

        
        logger.info(f"ELE [{i:03d}/{n_ele}][{n_valid_ch}-{n_all_channel}]: {ele_list[i][0]}")


        # Iteration by channel
        for j in _data_group['Channels']:
            try:
                _drt_data = _data_group[j]["DRTlist"]
                # _eis_data = _data_group[j]["EISlist"]
                _low_data = _data_group[j]["Loesslist"]

                eis_seq = _data_group[j]["eis_seq"]
                _drt_data = [_drt_data[ii] for ii in eis_seq]
                # _eis_data = [_eis_data[ii] for ii in eis_seq]
                _low_data = [_low_data[ii] for ii in eis_seq]

                _id_date = np.array(_x_date)
                _id_date = _id_date[eis_seq]

                vitro0_data_list.append(_drt_data)
                vitro0_start_list.append(_drt_data[0])

                vitro0_low_list.append(_low_data)

                _ch_id = j

                _id = [i, _ch_id] * len(_drt_data)
                _id = np.array(_id).reshape(-1,2)
                _eis_cluster = _data_group[j]['eis_cluster']
                _id = np.hstack((_id, _eis_cluster.reshape(-1,1)))
                _id = np.hstack((_id, _id_date.reshape(-1,1)))
                
                vitro0_id_list.append(_id)
                vitro0_start_id_list.append(_id[0,:])

            except Exception as e:
                logger.error(f"ELE[{ele_id}] - ch[{j:03d}] Run with error: {e}")
                continue




    vitro0_ele_list = [i[1] for i in ele_list]

    logger.info(f"Total {len(vitro0_data_list)} data points from {n_avaliable} electrodes")

    del data_pt, _meta_group, _data_group, _drt_data
# Out:
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_20504\4006158914.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_pt = torch.load(fd_pt)
# 2025-07-24 15:21:44.966 | INFO     | __main__:<module>:39 - ELE [000/218][127-127]: D:/Baihm/EISNN/Archive/01037160_归档
# 2025-07-24 15:21:53.547 | INFO     | __main__:<module>:39 - ELE [001/218][125-252]: D:/Baihm/EISNN/Archive/01037161_归档
# 2025-07-24 15:22:05.818 | INFO     | __main__:<module>:39 - ELE [002/218][128-380]: D:/Baihm/EISNN/Archive/01037162_归档
# 2025-07-24 15:22:10.179 | INFO     | __main__:<module>:39 - ELE [003/218][68-448]: D:/Baihm/EISNN/Archive/01067093_归档
# 2025-07-24 15:22:14.112 | INFO     | __main__:<module>:39 - ELE [004/218][61-509]: D:/Baihm/EISNN/Archive/01067094_归档
# 2025-07-24 15:22:19.577 | INFO     | __main__:<module>:39 - ELE [005/218][71-580]: D:/Baihm/EISNN/Archive/01067095_归档
# 2025-07-24 15:22:20.061 | INFO     | __main__:<module>:39 - ELE [006/218][12-592]: D:/Baihm/EISNN/Archive/02017384_归档
# 2025-07-24 15:22:22.695 | INFO     | __main__:<module>:39 - ELE [007/218][56-648]: D:/Baihm/EISNN/Archive/02017385_归档
# 2025-07-24 15:22:23.499 | INFO     | __main__:<module>:39 - ELE [008/218][22-670]: D:/Baihm/EISNN/Archive/02017387_归档
# 2025-07-24 15:22:29.449 | INFO     | __main__:<module>:39 - ELE [009/218][116-786]: D:/Baihm/EISNN/Archive/02027373_归档
# 2025-07-24 15:22:32.574 | INFO     | __main__:<module>:39 - ELE [010/218][82-868]: D:/Baihm/EISNN/Archive/02027390_归档
# 2025-07-24 15:22:38.407 | INFO     | __main__:<module>:39 - ELE [011/218][85-953]: D:/Baihm/EISNN/Archive/02027393_归档
# 2025-07-24 15:22:42.077 | INFO     | __main__:<module>:39 - ELE [012/218][103-1056]: D:/Baihm/EISNN/Archive/02027406_归档
# 2025-07-24 15:22:46.077 | INFO     | __main__:<module>:39 - ELE [013/218][96-1152]: D:/Baihm/EISNN/Archive/02027407_归档
# 2025-07-24 15:22:49.957 | INFO     | __main__:<module>:39 - ELE [014/218][100-1252]: D:/Baihm/EISNN/Archive/02027408_归档
# 2025-07-24 15:22:54.076 | INFO     | __main__:<module>:39 - ELE [015/218][106-1358]: D:/Baihm/EISNN/Archive/02027409_归档
# 2025-07-24 15:22:58.874 | INFO     | __main__:<module>:39 - ELE [016/218][112-1470]: D:/Baihm/EISNN/Archive/02027410_归档
# 2025-07-24 15:22:58.876 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/02027426_归档\Outlier_Ver04_DRTLoe_Ver02\02027426_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:23:03.325 | INFO     | __main__:<module>:39 - ELE [018/218][79-1549]: D:/Baihm/EISNN/Archive/02067447_归档
# 2025-07-24 15:23:05.984 | INFO     | __main__:<module>:39 - ELE [019/218][67-1616]: D:/Baihm/EISNN/Archive/02067448_归档
# 2025-07-24 15:23:05.985 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/02067449_归档\Outlier_Ver04_DRTLoe_Ver02\02067449_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:23:08.373 | INFO     | __main__:<module>:39 - ELE [021/218][68-1684]: D:/Baihm/EISNN/Archive/02067450_归档
# 2025-07-24 15:23:20.048 | INFO     | __main__:<module>:39 - ELE [022/218][126-1810]: D:/Baihm/EISNN/Archive/05087163_归档
# 2025-07-24 15:23:28.142 | INFO     | __main__:<module>:39 - ELE [023/218][120-1930]: D:/Baihm/EISNN/Archive/05087164_归档
# 2025-07-24 15:23:41.290 | INFO     | __main__:<module>:39 - ELE [024/218][126-2056]: D:/Baihm/EISNN/Archive/05097165_归档
# 2025-07-24 15:23:48.913 | INFO     | __main__:<module>:39 - ELE [025/218][126-2182]: D:/Baihm/EISNN/Archive/05097166_归档
# 2025-07-24 15:23:54.352 | INFO     | __main__:<module>:39 - ELE [026/218][125-2307]: D:/Baihm/EISNN/Archive/05107167_归档
# 2025-07-24 15:24:04.605 | INFO     | __main__:<module>:39 - ELE [027/218][127-2434]: D:/Baihm/EISNN/Archive/05107180_归档
# 2025-07-24 15:24:12.045 | INFO     | __main__:<module>:39 - ELE [028/218][127-2561]: D:/Baihm/EISNN/Archive/05117174_归档
# 2025-07-24 15:24:21.574 | INFO     | __main__:<module>:39 - ELE [029/218][127-2688]: D:/Baihm/EISNN/Archive/05117178_归档
# 2025-07-24 15:24:30.916 | INFO     | __main__:<module>:39 - ELE [030/218][127-2815]: D:/Baihm/EISNN/Archive/05127168_归档
# 2025-07-24 15:24:38.230 | INFO     | __main__:<module>:39 - ELE [031/218][119-2934]: D:/Baihm/EISNN/Archive/05127177_归档
# 2025-07-24 15:24:46.225 | INFO     | __main__:<module>:39 - ELE [032/218][123-3057]: D:/Baihm/EISNN/Archive/06017403_归档
# 2025-07-24 15:24:49.493 | INFO     | __main__:<module>:39 - ELE [033/218][97-3154]: D:/Baihm/EISNN/Archive/06017404_归档
# 2025-07-24 15:24:53.996 | INFO     | __main__:<module>:39 - ELE [034/218][115-3269]: D:/Baihm/EISNN/Archive/06017405_归档
# 2025-07-24 15:25:03.270 | INFO     | __main__:<module>:39 - ELE [035/218][67-3336]: D:/Baihm/EISNN/Archive/06017758_归档
# 2025-07-24 15:25:09.648 | INFO     | __main__:<module>:39 - ELE [036/218][54-3390]: D:/Baihm/EISNN/Archive/06017760_归档
# 2025-07-24 15:25:15.341 | INFO     | __main__:<module>:39 - ELE [037/218][70-3460]: D:/Baihm/EISNN/Archive/06047729_归档
# 2025-07-24 15:25:19.631 | INFO     | __main__:<module>:39 - ELE [038/218][41-3501]: D:/Baihm/EISNN/Archive/06047730_归档
# 2025-07-24 15:25:24.268 | INFO     | __main__:<module>:39 - ELE [039/218][54-3555]: D:/Baihm/EISNN/Archive/06047731_归档
# 2025-07-24 15:25:29.576 | INFO     | __main__:<module>:39 - ELE [040/218][121-3676]: D:/Baihm/EISNN/Archive/08260405_归档
# 2025-07-24 15:25:38.854 | INFO     | __main__:<module>:39 - ELE [041/218][127-3803]: D:/Baihm/EISNN/Archive/08260407_归档
# 2025-07-24 15:25:47.963 | INFO     | __main__:<module>:39 - ELE [042/218][127-3930]: D:/Baihm/EISNN/Archive/08260408_归档
# 2025-07-24 15:25:47.965 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09027195_归档\Outlier_Ver04_DRTLoe_Ver02\09027195_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:47.965 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09027196_归档\Outlier_Ver04_DRTLoe_Ver02\09027196_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:47.966 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09027197_归档\Outlier_Ver04_DRTLoe_Ver02\09027197_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:47.966 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047398_归档\Outlier_Ver04_DRTLoe_Ver02\09047398_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:47.966 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047399_归档\Outlier_Ver04_DRTLoe_Ver02\09047399_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:47.967 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047400_归档\Outlier_Ver04_DRTLoe_Ver02\09047400_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:47.967 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047411_归档\Outlier_Ver04_DRTLoe_Ver02\09047411_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:51.231 | INFO     | __main__:<module>:39 - ELE [050/218][90-4020]: D:/Baihm/EISNN/Archive/09047412_归档
# 2025-07-24 15:25:51.232 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047413_归档\Outlier_Ver04_DRTLoe_Ver02\09047413_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:51.233 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047414_归档\Outlier_Ver04_DRTLoe_Ver02\09047414_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:53.282 | INFO     | __main__:<module>:39 - ELE [053/218][60-4080]: D:/Baihm/EISNN/Archive/09047415_归档
# 2025-07-24 15:25:53.283 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047416_归档\Outlier_Ver04_DRTLoe_Ver02\09047416_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:55.743 | INFO     | __main__:<module>:39 - ELE [055/218][72-4152]: D:/Baihm/EISNN/Archive/09047417_归档
# 2025-07-24 15:25:55.745 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047418_归档\Outlier_Ver04_DRTLoe_Ver02\09047418_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:55.745 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047419_归档\Outlier_Ver04_DRTLoe_Ver02\09047419_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:55.745 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047490_归档\Outlier_Ver04_DRTLoe_Ver02\09047490_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:55.746 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09047491_归档\Outlier_Ver04_DRTLoe_Ver02\09047491_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:25:58.528 | INFO     | __main__:<module>:39 - ELE [060/218][78-4230]: D:/Baihm/EISNN/Archive/09047492_归档
# 2025-07-24 15:25:59.982 | INFO     | __main__:<module>:39 - ELE [061/218][43-4273]: D:/Baihm/EISNN/Archive/09060401_归档
# 2025-07-24 15:26:01.566 | INFO     | __main__:<module>:39 - ELE [062/218][49-4322]: D:/Baihm/EISNN/Archive/09060402_归档
# 2025-07-24 15:26:04.016 | INFO     | __main__:<module>:39 - ELE [063/218][73-4395]: D:/Baihm/EISNN/Archive/09060403_归档
# 2025-07-24 15:26:06.531 | INFO     | __main__:<module>:39 - ELE [064/218][78-4473]: D:/Baihm/EISNN/Archive/09190702_归档
# 2025-07-24 15:26:07.288 | INFO     | __main__:<module>:39 - ELE [065/218][21-4494]: D:/Baihm/EISNN/Archive/09190703_归档
# 2025-07-24 15:26:09.521 | INFO     | __main__:<module>:39 - ELE [066/218][69-4563]: D:/Baihm/EISNN/Archive/09190704_归档
# 2025-07-24 15:26:09.522 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09190801_归档\Outlier_Ver04_DRTLoe_Ver02\09190801_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:26:09.522 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09190802_归档\Outlier_Ver04_DRTLoe_Ver02\09190802_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:26:12.263 | INFO     | __main__:<module>:39 - ELE [069/218][70-4633]: D:/Baihm/EISNN/Archive/09207021_归档
# 2025-07-24 15:26:13.298 | INFO     | __main__:<module>:39 - ELE [070/218][24-4657]: D:/Baihm/EISNN/Archive/09207022_归档
# 2025-07-24 15:26:13.630 | INFO     | __main__:<module>:39 - ELE [071/218][7-4664]: D:/Baihm/EISNN/Archive/09207024_归档
# 2025-07-24 15:26:19.337 | INFO     | __main__:<module>:39 - ELE [072/218][70-4734]: D:/Baihm/EISNN/Archive/09207029_归档
# 2025-07-24 15:26:27.715 | INFO     | __main__:<module>:39 - ELE [073/218][72-4806]: D:/Baihm/EISNN/Archive/09207030_归档
# 2025-07-24 15:26:31.086 | INFO     | __main__:<module>:39 - ELE [074/218][63-4869]: D:/Baihm/EISNN/Archive/09207031_归档
# 2025-07-24 15:26:37.755 | INFO     | __main__:<module>:39 - ELE [075/218][116-4985]: D:/Baihm/EISNN/Archive/09230301_归档
# 2025-07-24 15:26:45.360 | INFO     | __main__:<module>:39 - ELE [076/218][125-5110]: D:/Baihm/EISNN/Archive/09230302_归档
# 2025-07-24 15:26:56.347 | INFO     | __main__:<module>:39 - ELE [077/218][127-5237]: D:/Baihm/EISNN/Archive/09230303_归档
# 2025-07-24 15:27:08.307 | INFO     | __main__:<module>:39 - ELE [078/218][127-5364]: D:/Baihm/EISNN/Archive/09230410_归档
# 2025-07-24 15:27:11.587 | INFO     | __main__:<module>:39 - ELE [079/218][82-5446]: D:/Baihm/EISNN/Archive/09230509_归档
# 2025-07-24 15:27:16.292 | INFO     | __main__:<module>:39 - ELE [080/218][121-5567]: D:/Baihm/EISNN/Archive/09230510_归档
# 2025-07-24 15:27:31.995 | INFO     | __main__:<module>:39 - ELE [081/218][126-5693]: D:/Baihm/EISNN/Archive/09230513_归档
# 2025-07-24 15:27:33.252 | INFO     | __main__:<module>:39 - ELE [082/218][32-5725]: D:/Baihm/EISNN/Archive/09230602_归档
# 2025-07-24 15:27:34.840 | INFO     | __main__:<module>:39 - ELE [083/218][45-5770]: D:/Baihm/EISNN/Archive/09230801_归档
# 2025-07-24 15:27:35.056 | INFO     | __main__:<module>:39 - ELE [084/218][4-5774]: D:/Baihm/EISNN/Archive/09231201_归档
# 2025-07-24 15:27:38.980 | INFO     | __main__:<module>:39 - ELE [085/218][67-5841]: D:/Baihm/EISNN/Archive/09231202_归档
# 2025-07-24 15:27:38.981 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231401_归档\Outlier_Ver04_DRTLoe_Ver02\09231401_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.982 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231402_归档\Outlier_Ver04_DRTLoe_Ver02\09231402_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.982 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231403_归档\Outlier_Ver04_DRTLoe_Ver02\09231403_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.983 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231404_归档\Outlier_Ver04_DRTLoe_Ver02\09231404_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.983 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231405_归档\Outlier_Ver04_DRTLoe_Ver02\09231405_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.984 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231406_归档\Outlier_Ver04_DRTLoe_Ver02\09231406_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.984 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231407_归档\Outlier_Ver04_DRTLoe_Ver02\09231407_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:38.985 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/09231408_归档\Outlier_Ver04_DRTLoe_Ver02\09231408_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:27:43.333 | INFO     | __main__:<module>:39 - ELE [094/218][102-5943]: D:/Baihm/EISNN/Archive/09231409_归档
# 2025-07-24 15:27:53.817 | INFO     | __main__:<module>:39 - ELE [095/218][126-6069]: D:/Baihm/EISNN/Archive/09250102_归档
# 2025-07-24 15:28:03.494 | INFO     | __main__:<module>:39 - ELE [096/218][123-6192]: D:/Baihm/EISNN/Archive/09250103_归档
# 2025-07-24 15:28:10.244 | INFO     | __main__:<module>:39 - ELE [097/218][116-6308]: D:/Baihm/EISNN/Archive/09250104_归档
# 2025-07-24 15:28:18.876 | INFO     | __main__:<module>:39 - ELE [098/218][128-6436]: D:/Baihm/EISNN/Archive/09250210_归档
# 2025-07-24 15:28:25.402 | INFO     | __main__:<module>:39 - ELE [099/218][123-6559]: D:/Baihm/EISNN/Archive/09290311_归档
# 2025-07-24 15:28:32.956 | INFO     | __main__:<module>:39 - ELE [100/218][128-6687]: D:/Baihm/EISNN/Archive/09290312_归档
# 2025-07-24 15:28:39.971 | INFO     | __main__:<module>:39 - ELE [101/218][124-6811]: D:/Baihm/EISNN/Archive/09290314_归档
# 2025-07-24 15:28:49.291 | INFO     | __main__:<module>:39 - ELE [102/218][128-6939]: D:/Baihm/EISNN/Archive/09290511_归档
# 2025-07-24 15:28:49.586 | INFO     | __main__:<module>:39 - ELE [103/218][6-6945]: D:/Baihm/EISNN/Archive/10017036_归档
# 2025-07-24 15:28:52.591 | INFO     | __main__:<module>:39 - ELE [104/218][64-7009]: D:/Baihm/EISNN/Archive/10017037_归档
# 2025-07-24 15:28:53.740 | INFO     | __main__:<module>:39 - ELE [105/218][25-7034]: D:/Baihm/EISNN/Archive/10017038_归档
# 2025-07-24 15:28:58.645 | INFO     | __main__:<module>:39 - ELE [106/218][68-7102]: D:/Baihm/EISNN/Archive/10037050_归档
# 2025-07-24 15:29:03.507 | INFO     | __main__:<module>:39 - ELE [107/218][68-7170]: D:/Baihm/EISNN/Archive/10037051_归档
# 2025-07-24 15:29:06.346 | INFO     | __main__:<module>:39 - ELE [108/218][62-7232]: D:/Baihm/EISNN/Archive/10037052_归档
# 2025-07-24 15:29:09.288 | INFO     | __main__:<module>:39 - ELE [109/218][63-7295]: D:/Baihm/EISNN/Archive/10047056_归档
# 2025-07-24 15:29:11.725 | INFO     | __main__:<module>:39 - ELE [110/218][56-7351]: D:/Baihm/EISNN/Archive/10047059_归档
# 2025-07-24 15:29:13.919 | INFO     | __main__:<module>:39 - ELE [111/218][49-7400]: D:/Baihm/EISNN/Archive/10047060_归档
# 2025-07-24 15:29:19.400 | INFO     | __main__:<module>:39 - ELE [112/218][67-7467]: D:/Baihm/EISNN/Archive/10057069_归档
# 2025-07-24 15:29:19.402 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/10057070_归档\Outlier_Ver04_DRTLoe_Ver02\10057070_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:29:22.267 | INFO     | __main__:<module>:39 - ELE [114/218][66-7533]: D:/Baihm/EISNN/Archive/10057071_归档
# 2025-07-24 15:29:22.614 | INFO     | __main__:<module>:39 - ELE [115/218][9-7542]: D:/Baihm/EISNN/Archive/10057083_归档
# 2025-07-24 15:29:26.310 | INFO     | __main__:<module>:39 - ELE [116/218][61-7603]: D:/Baihm/EISNN/Archive/10057084_归档
# 2025-07-24 15:29:31.230 | INFO     | __main__:<module>:39 - ELE [117/218][68-7671]: D:/Baihm/EISNN/Archive/10057087_归档
# 2025-07-24 15:29:33.501 | INFO     | __main__:<module>:39 - ELE [118/218][36-7707]: D:/Baihm/EISNN/Archive/10067077_归档
# 2025-07-24 15:29:33.978 | INFO     | __main__:<module>:39 - ELE [119/218][11-7718]: D:/Baihm/EISNN/Archive/10067078_归档
# 2025-07-24 15:29:38.856 | INFO     | __main__:<module>:39 - ELE [120/218][63-7781]: D:/Baihm/EISNN/Archive/10067080_归档
# 2025-07-24 15:29:45.321 | INFO     | __main__:<module>:39 - ELE [121/218][110-7891]: D:/Baihm/EISNN/Archive/10080508_归档
# 2025-07-24 15:29:51.925 | INFO     | __main__:<module>:39 - ELE [122/218][123-8014]: D:/Baihm/EISNN/Archive/10080509_归档
# 2025-07-24 15:29:57.555 | INFO     | __main__:<module>:39 - ELE [123/218][95-8109]: D:/Baihm/EISNN/Archive/10080510_归档
# 2025-07-24 15:30:03.698 | INFO     | __main__:<module>:39 - ELE [124/218][115-8224]: D:/Baihm/EISNN/Archive/10080601_归档
# 2025-07-24 15:30:03.700 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/10080602_归档\Outlier_Ver04_DRTLoe_Ver02\10080602_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:30:09.974 | INFO     | __main__:<module>:39 - ELE [126/218][123-8347]: D:/Baihm/EISNN/Archive/10080603_归档
# 2025-07-24 15:30:15.602 | INFO     | __main__:<module>:39 - ELE [127/218][123-8470]: D:/Baihm/EISNN/Archive/10080706_归档
# 2025-07-24 15:30:20.815 | INFO     | __main__:<module>:39 - ELE [128/218][125-8595]: D:/Baihm/EISNN/Archive/10080708_归档
# 2025-07-24 15:30:20.816 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/10086061_归档\Outlier_Ver04_DRTLoe_Ver02\10086061_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:30:20.817 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/10086063_归档\Outlier_Ver04_DRTLoe_Ver02\10086063_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:30:20.817 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/10086118_归档\Outlier_Ver04_DRTLoe_Ver02\10086118_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:30:25.762 | INFO     | __main__:<module>:39 - ELE [132/218][82-8677]: D:/Baihm/EISNN/Archive/10150201_归档
# 2025-07-24 15:30:34.279 | INFO     | __main__:<module>:39 - ELE [133/218][120-8797]: D:/Baihm/EISNN/Archive/10150202_归档
# 2025-07-24 15:30:43.135 | INFO     | __main__:<module>:39 - ELE [134/218][123-8920]: D:/Baihm/EISNN/Archive/10150203_归档
# 2025-07-24 15:30:50.932 | INFO     | __main__:<module>:39 - ELE [135/218][126-9046]: D:/Baihm/EISNN/Archive/10160301_归档
# 2025-07-24 15:30:57.855 | INFO     | __main__:<module>:39 - ELE [136/218][124-9170]: D:/Baihm/EISNN/Archive/10160302_归档
# 2025-07-24 15:30:58.494 | INFO     | __main__:<module>:39 - ELE [137/218][11-9181]: D:/Baihm/EISNN/Archive/10160303_归档
# 2025-07-24 15:31:06.274 | INFO     | __main__:<module>:39 - ELE [138/218][126-9307]: D:/Baihm/EISNN/Archive/10210301_归档
# 2025-07-24 15:31:13.374 | INFO     | __main__:<module>:39 - ELE [139/218][123-9430]: D:/Baihm/EISNN/Archive/10210302_归档
# 2025-07-24 15:31:20.429 | INFO     | __main__:<module>:39 - ELE [140/218][120-9550]: D:/Baihm/EISNN/Archive/10210303_归档
# 2025-07-24 15:31:20.431 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11017483_归档\Outlier_Ver04_DRTLoe_Ver02\11017483_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:20.432 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11017484_归档\Outlier_Ver04_DRTLoe_Ver02\11017484_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:20.432 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11026042_归档\Outlier_Ver04_DRTLoe_Ver02\11026042_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:20.433 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11026043_归档\Outlier_Ver04_DRTLoe_Ver02\11026043_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:20.433 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11026044_归档\Outlier_Ver04_DRTLoe_Ver02\11026044_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:25.173 | INFO     | __main__:<module>:39 - ELE [146/218][113-9663]: D:/Baihm/EISNN/Archive/11037454_归档
# 2025-07-24 15:31:25.175 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11037455_归档\Outlier_Ver04_DRTLoe_Ver02\11037455_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:25.176 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11037456_归档\Outlier_Ver04_DRTLoe_Ver02\11037456_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:31:30.034 | INFO     | __main__:<module>:39 - ELE [149/218][74-9737]: D:/Baihm/EISNN/Archive/11037715_归档
# 2025-07-24 15:31:35.553 | INFO     | __main__:<module>:39 - ELE [150/218][73-9810]: D:/Baihm/EISNN/Archive/11037716_归档
# 2025-07-24 15:31:40.527 | INFO     | __main__:<module>:39 - ELE [151/218][75-9885]: D:/Baihm/EISNN/Archive/11037717_归档
# 2025-07-24 15:31:45.606 | INFO     | __main__:<module>:39 - ELE [152/218][63-9948]: D:/Baihm/EISNN/Archive/11047722_归档
# 2025-07-24 15:31:50.789 | INFO     | __main__:<module>:39 - ELE [153/218][74-10022]: D:/Baihm/EISNN/Archive/11047725_归档
# 2025-07-24 15:31:56.280 | INFO     | __main__:<module>:39 - ELE [154/218][73-10095]: D:/Baihm/EISNN/Archive/11047726_归档
# 2025-07-24 15:31:59.217 | INFO     | __main__:<module>:39 - ELE [155/218][61-10156]: D:/Baihm/EISNN/Archive/11050201_归档
# 2025-07-24 15:31:59.586 | INFO     | __main__:<module>:39 - ELE [156/218][8-10164]: D:/Baihm/EISNN/Archive/11050202_归档
# 2025-07-24 15:32:01.679 | INFO     | __main__:<module>:39 - ELE [157/218][56-10220]: D:/Baihm/EISNN/Archive/11050203_归档
# 2025-07-24 15:32:06.921 | INFO     | __main__:<module>:39 - ELE [158/218][79-10299]: D:/Baihm/EISNN/Archive/11057709_归档
# 2025-07-24 15:32:11.316 | INFO     | __main__:<module>:39 - ELE [159/218][56-10355]: D:/Baihm/EISNN/Archive/11057710_归档
# 2025-07-24 15:32:18.549 | INFO     | __main__:<module>:39 - ELE [160/218][94-10449]: D:/Baihm/EISNN/Archive/11057712_归档
# 2025-07-24 15:32:18.551 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11057714_归档\Outlier_Ver04_DRTLoe_Ver02\11057714_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:25.269 | INFO     | __main__:<module>:39 - ELE [162/218][70-10519]: D:/Baihm/EISNN/Archive/11067222_归档
# 2025-07-24 15:32:32.166 | INFO     | __main__:<module>:39 - ELE [163/218][75-10594]: D:/Baihm/EISNN/Archive/11067223_归档
# 2025-07-24 15:32:38.139 | INFO     | __main__:<module>:39 - ELE [164/218][74-10668]: D:/Baihm/EISNN/Archive/11067224_归档
# 2025-07-24 15:32:38.141 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11077496_归档\Outlier_Ver04_DRTLoe_Ver02\11077496_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.141 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11077497_归档\Outlier_Ver04_DRTLoe_Ver02\11077497_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.141 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11077498_归档\Outlier_Ver04_DRTLoe_Ver02\11077498_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.142 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11207129_归档\Outlier_Ver04_DRTLoe_Ver02\11207129_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.142 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11207147_归档\Outlier_Ver04_DRTLoe_Ver02\11207147_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.143 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/11207149_归档\Outlier_Ver04_DRTLoe_Ver02\11207149_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.143 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/12027309_归档\Outlier_Ver04_DRTLoe_Ver02\12027309_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.144 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/12027320_归档\Outlier_Ver04_DRTLoe_Ver02\12027320_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.144 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/12120001_归档\Outlier_Ver04_DRTLoe_Ver02\12120001_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.144 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/12120101_归档\Outlier_Ver04_DRTLoe_Ver02\12120101_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.145 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/12201111_归档\Outlier_Ver04_DRTLoe_Ver02\12201111_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.145 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/15361101_归档\Outlier_Ver04_DRTLoe_Ver02\15361101_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.146 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/15361102_归档\Outlier_Ver04_DRTLoe_Ver02\15361102_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:38.146 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/15361104_归档\Outlier_Ver04_DRTLoe_Ver02\15361104_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:32:41.406 | INFO     | __main__:<module>:39 - ELE [179/218][66-10734]: D:/Baihm/EISNN/Archive/16037225_归档
# 2025-07-24 15:32:45.623 | INFO     | __main__:<module>:39 - ELE [180/218][81-10815]: D:/Baihm/EISNN/Archive/16037226_归档
# 2025-07-24 15:32:49.675 | INFO     | __main__:<module>:39 - ELE [181/218][76-10891]: D:/Baihm/EISNN/Archive/16037227_归档
# 2025-07-24 15:32:51.514 | INFO     | __main__:<module>:39 - ELE [182/218][25-10916]: D:/Baihm/EISNN/Archive/20037515_归档
# 2025-07-24 15:32:53.163 | INFO     | __main__:<module>:39 - ELE [183/218][26-10942]: D:/Baihm/EISNN/Archive/20037516_归档
# 2025-07-24 15:32:55.219 | INFO     | __main__:<module>:39 - ELE [184/218][33-10975]: D:/Baihm/EISNN/Archive/20037517_归档
# 2025-07-24 15:32:58.720 | INFO     | __main__:<module>:39 - ELE [185/218][69-11044]: D:/Baihm/EISNN/Archive/20057520_归档
# 2025-07-24 15:33:04.395 | INFO     | __main__:<module>:39 - ELE [186/218][80-11124]: D:/Baihm/EISNN/Archive/20057521_归档
# 2025-07-24 15:33:07.706 | INFO     | __main__:<module>:39 - ELE [187/218][76-11200]: D:/Baihm/EISNN/Archive/20067523_归档
# 2025-07-24 15:33:10.855 | INFO     | __main__:<module>:39 - ELE [188/218][75-11275]: D:/Baihm/EISNN/Archive/20067524_归档
# 2025-07-24 15:33:16.134 | INFO     | __main__:<module>:39 - ELE [189/218][73-11348]: D:/Baihm/EISNN/Archive/20067525_归档
# 2025-07-24 15:33:16.889 | INFO     | __main__:<module>:39 - ELE [190/218][21-11369]: D:/Baihm/EISNN/Archive/22017367_归档
# 2025-07-24 15:33:16.890 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/22017368_归档\Outlier_Ver04_DRTLoe_Ver02\22017368_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:17.692 | INFO     | __main__:<module>:39 - ELE [192/218][23-11392]: D:/Baihm/EISNN/Archive/22017369_归档
# 2025-07-24 15:33:22.471 | INFO     | __main__:<module>:39 - ELE [193/218][82-11474]: D:/Baihm/EISNN/Archive/22017370_归档
# 2025-07-24 15:33:23.224 | INFO     | __main__:<module>:39 - ELE [194/218][21-11495]: D:/Baihm/EISNN/Archive/22017371_归档
# 2025-07-24 15:33:27.369 | INFO     | __main__:<module>:39 - ELE [195/218][71-11566]: D:/Baihm/EISNN/Archive/22017372_归档
# 2025-07-24 15:33:27.370 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/22027364_归档\Outlier_Ver04_DRTLoe_Ver02\22027364_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:28.738 | INFO     | __main__:<module>:39 - ELE [197/218][24-11590]: D:/Baihm/EISNN/Archive/22027365_归档
# 2025-07-24 15:33:29.230 | INFO     | __main__:<module>:39 - ELE [198/218][13-11603]: D:/Baihm/EISNN/Archive/22027366_归档
# 2025-07-24 15:33:30.259 | INFO     | __main__:<module>:39 - ELE [199/218][26-11629]: D:/Baihm/EISNN/Archive/22037378_归档
# 2025-07-24 15:33:32.181 | INFO     | __main__:<module>:39 - ELE [200/218][51-11680]: D:/Baihm/EISNN/Archive/22037379_归档
# 2025-07-24 15:33:36.668 | INFO     | __main__:<module>:39 - ELE [201/218][73-11753]: D:/Baihm/EISNN/Archive/22037380_归档
# 2025-07-24 15:33:37.903 | INFO     | __main__:<module>:39 - ELE [202/218][33-11786]: D:/Baihm/EISNN/Archive/22047374_归档
# 2025-07-24 15:33:38.937 | INFO     | __main__:<module>:39 - ELE [203/218][28-11814]: D:/Baihm/EISNN/Archive/22047376_归档
# 2025-07-24 15:33:39.737 | INFO     | __main__:<module>:39 - ELE [204/218][21-11835]: D:/Baihm/EISNN/Archive/22047377_归档
# 2025-07-24 15:33:39.738 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/23066051_归档\Outlier_Ver04_DRTLoe_Ver02\23066051_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:39.739 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/23066053_归档\Outlier_Ver04_DRTLoe_Ver02\23066053_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:39.739 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/23066054_归档\Outlier_Ver04_DRTLoe_Ver02\23066054_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:39.739 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/23177394_归档\Outlier_Ver04_DRTLoe_Ver02\23177394_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:39.740 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/23177395_归档\Outlier_Ver04_DRTLoe_Ver02\23177395_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:45.707 | INFO     | __main__:<module>:39 - ELE [210/218][117-11952]: D:/Baihm/EISNN/Archive/23177396_归档
# 2025-07-24 15:33:45.709 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/24091971_归档\Outlier_Ver04_DRTLoe_Ver02\24091971_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:45.709 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/24091972_归档\Outlier_Ver04_DRTLoe_Ver02\24091972_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:45.709 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/24091981_归档\Outlier_Ver04_DRTLoe_Ver02\24091981_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:45.710 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/24091982_归档\Outlier_Ver04_DRTLoe_Ver02\24091982_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:45.710 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/29036055_归档\Outlier_Ver04_DRTLoe_Ver02\29036055_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:45.710 | WARNING  | __main__:<module>:17 - D:/Baihm/EISNN/Archive/29036056_归档\Outlier_Ver04_DRTLoe_Ver02\29036056_Outlier_Ver04_DRTLoe_Ver02.pt does not exist
# 2025-07-24 15:33:51.095 | INFO     | __main__:<module>:39 - ELE [217/218][119-12071]: D:/Baihm/EISNN/Archive/29036057_归档
# 2025-07-24 15:33:51.097 | INFO     | __main__:<module>:82 - Total 12071 data points from 152 electrodes

# %%
len(vitro0_data_list[0][0][0])
# Out:
# 3

# %% [markdown]
# ### Plot Start Data

# %%
# 创建窗口

app = pg.mkQApp()
win = pg.GraphicsLayoutWidget(show=True, title="Big Scatter Plot")
plot = win.addPlot()
plot.setWindowTitle('2e7 Points Scatter')
plot.setAspectLocked(False)

# 加载和flatten数据（你已有这步）
x_list = []
y_list = []

for i in range(len(vitro0_data_list)):
    for j in range(len(vitro0_start_list[i])):
    # for j in range(1):
        x = vitro0_start_list[i][j][1, :]
        y = vitro0_start_list[i][j][2, :]
        x_list.append(x)
        y_list.append(y)

x_all = np.concatenate(x_list).astype(np.float32)
y_all = np.concatenate(y_list).astype(np.float32)
# x_all = x_all[:10000]
# y_all = y_all[:10000]

scatter = pg.ScatterPlotItem(size=1, pen=None, brush=(255, 255, 255, 20))

# scatter.setData(x=np.log10(x_all), y=np.log10(y_all))
scatter.setData(x=np.log10(x_all)+np.log10(y_all), y=np.log10(x_all)-np.log10(y_all))

plot.addItem(scatter)
plot.setLogMode(x=True, y=True)

# %% [markdown]
# ### Plot All Data

# %%
# 创建窗口

app = pg.mkQApp()
win = pg.GraphicsLayoutWidget(show=True, title="Big Scatter Plot")
plot = win.addPlot()
plot.setWindowTitle('2e7 Points Scatter')
plot.setAspectLocked(False)

# 加载和flatten数据（你已有这步）
x_list = []
y_list = []

for i in range(len(vitro0_data_list)):
    for j in range(len(vitro0_data_list[i])):
        # for k in range(len(vitro0_data_list[i][j])):
        for k in range(20,22):
            x = vitro0_data_list[i][j][k][1, :]
            y = vitro0_data_list[i][j][k][2, :]
            x_list.append(x)
            y_list.append(y)

x_all = np.concatenate(x_list).astype(np.float32)
y_all = np.concatenate(y_list).astype(np.float32)
# x_all = x_all[:10000]
# y_all = y_all[:10000]

scatter = pg.ScatterPlotItem(size=1, pen=None, brush=(255, 255, 255, 20))

# scatter.setData(x=np.log10(x_all), y=np.log10(y_all))
# scatter.setData(x=np.log10(x_all)+np.log10(y_all), y=np.log10(x_all)-np.log10(y_all))

_tt = x_all * y_all
_yy = x_all / y_all
_yy = _yy / (((_tt/1e-7)**-1) + ((_tt/1e3)**1))
# _yy = (((_tt/1e-7)**-1) + ((_tt/1e3)**1))
scatter.setData(x=np.log10(_tt), y=np.log10(_yy))

plot.addItem(scatter)
plot.setLogMode(x=True, y=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.logspace(-7, 1, 1000)
# y = (x/1e3)**-1 + (x/1e-7)**1
y = (x/1e-7)**-1 + (x/1e3)**1

plt.loglog(x, y)
plt.xlabel("x (log scale)")
plt.ylabel("y (log scale)")
plt.title("y = A*x^-α + B*x^β")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Extract Lowess

# %%
vitro0_lowess_list = []
# for i in range(len(vitro0_data_list)):
for i in range(20):
    for j in range(len(vitro0_data_list[i])):
        DRTdata_Loess = DRT_Lowess(vitro0_data_list[i][j])
        vitro0_lowess_list.append(DRTdata_Loess)
    if i%10 == 0:
        logger.info(f"Lowess [{i}/{len(vitro0_data_list)}]")
# Out:
# 2025-07-24 15:58:46.821 | INFO     | __main__:<module>:8 - Lowess [0/12071]
# 2025-07-24 15:58:51.639 | INFO     | __main__:<module>:8 - Lowess [10/12071]

# %%
# vitro0_lowess_align_list = []
# for i in range(len(vitro0_start_list)):
# # for i in range(3):
#     DRTdata_Loess = DRT_Lowess(vitro0_start_list[i])
#     vitro0_lowess_align_list.append(DRTdata_Loess)
#     if i%100 == 0:
#         logger.info(f"Lowess [{i}/{len(vitro0_start_list)}]")
# Out:
# 2025-07-24 14:51:10.307 | INFO     | __main__:<module>:7 - Lowess [0/12071]

# %% [markdown]
# ### Plot Lowess

# %%
import numpy as np
import pyqtgraph as pg
# %gui qt
# 创建窗口

app = pg.mkQApp()
win = pg.GraphicsLayoutWidget(show=True, title="Big Scatter Plot")
plot = win.addPlot()
plot.setWindowTitle('2e7 Points Scatter')
plot.setAspectLocked(False)

# 加载和flatten数据（你已有这步）
x_list = []
y_list = []

for i in range(len(vitro0_lowess_list)):
        x = vitro0_lowess_list[i][1, :]
        y = vitro0_lowess_list[i][2, :]
        x_list.append(x)
        y_list.append(y)

x_all = np.concatenate(x_list).astype(np.float32)
y_all = np.concatenate(y_list).astype(np.float32)
# x_all = x_all[:10000]
# y_all = y_all[:10000]

scatter = pg.ScatterPlotItem(size=1, pen=None, brush=(255, 255, 255, 50))
# scatter.setData(x=np.log10(x_all), y=np.log10(y_all))
# scatter.setData(x=np.log10(x_all)+np.log10(y_all), y=np.log10(x_all)-np.log10(y_all))
scatter.setData(x=np.log10(x_all)+np.log10(y_all), y=np.log10(x_all))
# scatter.setData(x=np.log10(x_all)+np.log10(y_all), y=-np.log10(y_all))

plot.addItem(scatter)
plot.setLogMode(x=True, y=True)
# plot.setLogMode(x=True, y=False)

# %% [markdown]
# # Archive Old - Tik

# %% [markdown]
# ## Extract All Data

# %%
if READ_RAW_FLAG:
    rootPath = "D:/Baihm/EISNN/Archive/"
    ele_list = SearchELE(rootPath, re.compile(r"(.+?)_归档"))
    DATASET_SUFFIX = "Outlier_Ver04"


    n_ele = len(ele_list)
    logger.info(f"Search in {rootPath} and find {n_ele:03d} electrodes")
# Out:
# 2025-07-24 13:43:39.767 | INFO     | __main__:<module>:8 - Search in D:/Baihm/EISNN/Archive/ and find 218 electrodes

# %%
if READ_RAW_FLAG:
    DRT_SUFFIX = f"{DATASET_SUFFIX}_DRTTik_Ver01"

    Loe_vitro0_start_list = []
    Loe_vitro0_start_id_list = []
    Loe_vitro0_data_list = []
    Loe_vitro0_id_list = []

    n_avaliable = 0
    n_all_channel = 0

    for i in range(n_ele):
    # for i in range(3):
        fd_pt = os.path.join(ele_list[i][0], DRT_SUFFIX, f"{ele_list[i][1]}_{DRT_SUFFIX}.pt")
        if not os.path.exists(fd_pt):
            logger.warning(f"{fd_pt} does not exist")
            continue


        data_pt = torch.load(fd_pt)
        _meta_group = data_pt["meta_group"]
        _data_group = data_pt["data_group"]


        ele_id  = _meta_group["ele_id"]
        elePath = _meta_group["elePath"]
        n_ch = _meta_group["n_ch"]      
        n_valid_ch  = len(_data_group["Channels"])

        x_day_full = _meta_group["TimeSpan"]
        _x_date = np.array([(poi - x_day_full[0]).days for poi in x_day_full])


        n_avaliable = n_avaliable + 1
        n_all_channel = n_all_channel + n_valid_ch

        
        logger.info(f"ELE [{i:03d}/{n_ele}][{n_valid_ch}-{n_all_channel}]: {ele_list[i][0]}")


        # Iteration by channel
        for j in _data_group['Channels']:
            try:
                _drt_data = _data_group[j]["DRTdata"]
                _drt_data = [ii[[2,0,1],:] for ii in _drt_data]
                # _id_date = np.array(_x_date)
                # _id_date = _id_date[eis_seq]

                Loe_vitro0_data_list.append(_drt_data)
                Loe_vitro0_start_list.append(_drt_data[0])


                # _ch_id = j

                # _id = [i, _ch_id] * len(_drt_data)
                # _id = np.array(_id).reshape(-1,2)
                # _eis_cluster = _data_group[j]['eis_cluster']
                # _id = np.hstack((_id, _eis_cluster.reshape(-1,1)))
                # _id = np.hstack((_id, _id_date.reshape(-1,1)))
                
                # Loe_vitro0_id_list.append(_id)
                # Loe_vitro0_start_id_list.append(_id[0,:])

            except Exception as e:
                logger.error(f"ELE[{ele_id}] - ch[{j:03d}] Run with error: {e}")
                continue




    Loe_vitro0_ele_list = [i[1] for i in ele_list]

    logger.info(f"Total {len(Loe_vitro0_data_list)} data points from {n_avaliable} electrodes")

    del data_pt, _meta_group, _data_group, _drt_data
# Out:
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_20504\545717968.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_pt = torch.load(fd_pt)
# 2025-07-24 14:02:26.606 | INFO     | __main__:<module>:38 - ELE [000/218][127-127]: D:/Baihm/EISNN/Archive/01037160_归档
# 2025-07-24 14:02:26.654 | INFO     | __main__:<module>:38 - ELE [001/218][125-252]: D:/Baihm/EISNN/Archive/01037161_归档
# 2025-07-24 14:02:26.717 | INFO     | __main__:<module>:38 - ELE [002/218][128-380]: D:/Baihm/EISNN/Archive/01037162_归档
# 2025-07-24 14:02:26.742 | INFO     | __main__:<module>:38 - ELE [003/218][68-448]: D:/Baihm/EISNN/Archive/01067093_归档
# 2025-07-24 14:02:26.759 | INFO     | __main__:<module>:38 - ELE [004/218][61-509]: D:/Baihm/EISNN/Archive/01067094_归档
# 2025-07-24 14:02:26.789 | INFO     | __main__:<module>:38 - ELE [005/218][71-580]: D:/Baihm/EISNN/Archive/01067095_归档
# 2025-07-24 14:02:26.792 | INFO     | __main__:<module>:38 - ELE [006/218][12-592]: D:/Baihm/EISNN/Archive/02017384_归档
# 2025-07-24 14:02:26.806 | INFO     | __main__:<module>:38 - ELE [007/218][56-648]: D:/Baihm/EISNN/Archive/02017385_归档
# 2025-07-24 14:02:26.811 | INFO     | __main__:<module>:38 - ELE [008/218][22-670]: D:/Baihm/EISNN/Archive/02017387_归档
# 2025-07-24 14:02:26.845 | INFO     | __main__:<module>:38 - ELE [009/218][116-786]: D:/Baihm/EISNN/Archive/02027373_归档
# 2025-07-24 14:02:26.864 | INFO     | __main__:<module>:38 - ELE [010/218][82-868]: D:/Baihm/EISNN/Archive/02027390_归档
# 2025-07-24 14:02:26.898 | INFO     | __main__:<module>:38 - ELE [011/218][85-953]: D:/Baihm/EISNN/Archive/02027393_归档
# 2025-07-24 14:02:26.919 | INFO     | __main__:<module>:38 - ELE [012/218][103-1056]: D:/Baihm/EISNN/Archive/02027406_归档
# 2025-07-24 14:02:26.942 | INFO     | __main__:<module>:38 - ELE [013/218][96-1152]: D:/Baihm/EISNN/Archive/02027407_归档
# 2025-07-24 14:02:26.967 | INFO     | __main__:<module>:38 - ELE [014/218][100-1252]: D:/Baihm/EISNN/Archive/02027408_归档
# 2025-07-24 14:02:26.990 | INFO     | __main__:<module>:38 - ELE [015/218][106-1358]: D:/Baihm/EISNN/Archive/02027409_归档
# 2025-07-24 14:02:27.016 | INFO     | __main__:<module>:38 - ELE [016/218][112-1470]: D:/Baihm/EISNN/Archive/02027410_归档
# 2025-07-24 14:02:27.018 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/02027426_归档\Outlier_Ver04_DRTTik_Ver01\02027426_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.040 | INFO     | __main__:<module>:38 - ELE [018/218][79-1549]: D:/Baihm/EISNN/Archive/02067447_归档
# 2025-07-24 14:02:27.055 | INFO     | __main__:<module>:38 - ELE [019/218][67-1616]: D:/Baihm/EISNN/Archive/02067448_归档
# 2025-07-24 14:02:27.056 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/02067449_归档\Outlier_Ver04_DRTTik_Ver01\02067449_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.068 | INFO     | __main__:<module>:38 - ELE [021/218][68-1684]: D:/Baihm/EISNN/Archive/02067450_归档
# 2025-07-24 14:02:27.126 | INFO     | __main__:<module>:38 - ELE [022/218][126-1810]: D:/Baihm/EISNN/Archive/05087163_归档
# 2025-07-24 14:02:27.170 | INFO     | __main__:<module>:38 - ELE [023/218][120-1930]: D:/Baihm/EISNN/Archive/05087164_归档
# 2025-07-24 14:02:27.237 | INFO     | __main__:<module>:38 - ELE [024/218][126-2056]: D:/Baihm/EISNN/Archive/05097165_归档
# 2025-07-24 14:02:27.279 | INFO     | __main__:<module>:38 - ELE [025/218][126-2182]: D:/Baihm/EISNN/Archive/05097166_归档
# 2025-07-24 14:02:27.311 | INFO     | __main__:<module>:38 - ELE [026/218][125-2307]: D:/Baihm/EISNN/Archive/05107167_归档
# 2025-07-24 14:02:27.364 | INFO     | __main__:<module>:38 - ELE [027/218][127-2434]: D:/Baihm/EISNN/Archive/05107180_归档
# 2025-07-24 14:02:27.408 | INFO     | __main__:<module>:38 - ELE [028/218][127-2561]: D:/Baihm/EISNN/Archive/05117174_归档
# 2025-07-24 14:02:27.459 | INFO     | __main__:<module>:38 - ELE [029/218][127-2688]: D:/Baihm/EISNN/Archive/05117178_归档
# 2025-07-24 14:02:27.509 | INFO     | __main__:<module>:38 - ELE [030/218][127-2815]: D:/Baihm/EISNN/Archive/05127168_归档
# 2025-07-24 14:02:27.549 | INFO     | __main__:<module>:38 - ELE [031/218][119-2934]: D:/Baihm/EISNN/Archive/05127177_归档
# 2025-07-24 14:02:27.600 | INFO     | __main__:<module>:38 - ELE [032/218][123-3057]: D:/Baihm/EISNN/Archive/06017403_归档
# 2025-07-24 14:02:27.620 | INFO     | __main__:<module>:38 - ELE [033/218][97-3154]: D:/Baihm/EISNN/Archive/06017404_归档
# 2025-07-24 14:02:27.646 | INFO     | __main__:<module>:38 - ELE [034/218][115-3269]: D:/Baihm/EISNN/Archive/06017405_归档
# 2025-07-24 14:02:27.692 | INFO     | __main__:<module>:38 - ELE [035/218][67-3336]: D:/Baihm/EISNN/Archive/06017758_归档
# 2025-07-24 14:02:27.725 | INFO     | __main__:<module>:38 - ELE [036/218][54-3390]: D:/Baihm/EISNN/Archive/06017760_归档
# 2025-07-24 14:02:27.754 | INFO     | __main__:<module>:38 - ELE [037/218][70-3460]: D:/Baihm/EISNN/Archive/06047729_归档
# 2025-07-24 14:02:27.778 | INFO     | __main__:<module>:38 - ELE [038/218][41-3501]: D:/Baihm/EISNN/Archive/06047730_归档
# 2025-07-24 14:02:27.805 | INFO     | __main__:<module>:38 - ELE [039/218][54-3555]: D:/Baihm/EISNN/Archive/06047731_归档
# 2025-07-24 14:02:27.833 | INFO     | __main__:<module>:38 - ELE [040/218][121-3676]: D:/Baihm/EISNN/Archive/08260405_归档
# 2025-07-24 14:02:27.879 | INFO     | __main__:<module>:38 - ELE [041/218][127-3803]: D:/Baihm/EISNN/Archive/08260407_归档
# 2025-07-24 14:02:27.923 | INFO     | __main__:<module>:38 - ELE [042/218][127-3930]: D:/Baihm/EISNN/Archive/08260408_归档
# 2025-07-24 14:02:27.925 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09027195_归档\Outlier_Ver04_DRTTik_Ver01\09027195_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.926 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09027196_归档\Outlier_Ver04_DRTTik_Ver01\09027196_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.926 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09027197_归档\Outlier_Ver04_DRTTik_Ver01\09027197_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.926 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047398_归档\Outlier_Ver04_DRTTik_Ver01\09047398_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.927 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047399_归档\Outlier_Ver04_DRTTik_Ver01\09047399_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.927 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047400_归档\Outlier_Ver04_DRTTik_Ver01\09047400_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.928 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047411_归档\Outlier_Ver04_DRTTik_Ver01\09047411_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.946 | INFO     | __main__:<module>:38 - ELE [050/218][90-4020]: D:/Baihm/EISNN/Archive/09047412_归档
# 2025-07-24 14:02:27.947 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047413_归档\Outlier_Ver04_DRTTik_Ver01\09047413_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.947 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047414_归档\Outlier_Ver04_DRTTik_Ver01\09047414_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.959 | INFO     | __main__:<module>:38 - ELE [053/218][60-4080]: D:/Baihm/EISNN/Archive/09047415_归档
# 2025-07-24 14:02:27.960 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047416_归档\Outlier_Ver04_DRTTik_Ver01\09047416_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.974 | INFO     | __main__:<module>:38 - ELE [055/218][72-4152]: D:/Baihm/EISNN/Archive/09047417_归档
# 2025-07-24 14:02:27.975 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047418_归档\Outlier_Ver04_DRTTik_Ver01\09047418_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.976 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047419_归档\Outlier_Ver04_DRTTik_Ver01\09047419_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.976 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047490_归档\Outlier_Ver04_DRTTik_Ver01\09047490_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.976 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09047491_归档\Outlier_Ver04_DRTTik_Ver01\09047491_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:27.990 | INFO     | __main__:<module>:38 - ELE [060/218][78-4230]: D:/Baihm/EISNN/Archive/09047492_归档
# 2025-07-24 14:02:28.064 | INFO     | __main__:<module>:38 - ELE [061/218][43-4273]: D:/Baihm/EISNN/Archive/09060401_归档
# 2025-07-24 14:02:28.137 | INFO     | __main__:<module>:38 - ELE [062/218][49-4322]: D:/Baihm/EISNN/Archive/09060402_归档
# 2025-07-24 14:02:28.198 | INFO     | __main__:<module>:38 - ELE [063/218][73-4395]: D:/Baihm/EISNN/Archive/09060403_归档
# 2025-07-24 14:02:28.296 | INFO     | __main__:<module>:38 - ELE [064/218][78-4473]: D:/Baihm/EISNN/Archive/09190702_归档
# 2025-07-24 14:02:28.353 | INFO     | __main__:<module>:38 - ELE [065/218][21-4494]: D:/Baihm/EISNN/Archive/09190703_归档
# 2025-07-24 14:02:28.436 | INFO     | __main__:<module>:38 - ELE [066/218][69-4563]: D:/Baihm/EISNN/Archive/09190704_归档
# 2025-07-24 14:02:28.438 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09190801_归档\Outlier_Ver04_DRTTik_Ver01\09190801_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:28.439 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09190802_归档\Outlier_Ver04_DRTTik_Ver01\09190802_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:28.523 | INFO     | __main__:<module>:38 - ELE [069/218][70-4633]: D:/Baihm/EISNN/Archive/09207021_归档
# 2025-07-24 14:02:28.597 | INFO     | __main__:<module>:38 - ELE [070/218][24-4657]: D:/Baihm/EISNN/Archive/09207022_归档
# 2025-07-24 14:02:28.632 | INFO     | __main__:<module>:38 - ELE [071/218][7-4664]: D:/Baihm/EISNN/Archive/09207024_归档
# 2025-07-24 14:02:28.728 | INFO     | __main__:<module>:38 - ELE [072/218][70-4734]: D:/Baihm/EISNN/Archive/09207029_归档
# 2025-07-24 14:02:28.869 | INFO     | __main__:<module>:38 - ELE [073/218][72-4806]: D:/Baihm/EISNN/Archive/09207030_归档
# 2025-07-24 14:02:28.973 | INFO     | __main__:<module>:38 - ELE [074/218][63-4869]: D:/Baihm/EISNN/Archive/09207031_归档
# 2025-07-24 14:02:29.108 | INFO     | __main__:<module>:38 - ELE [075/218][116-4985]: D:/Baihm/EISNN/Archive/09230301_归档
# 2025-07-24 14:02:29.252 | INFO     | __main__:<module>:38 - ELE [076/218][125-5110]: D:/Baihm/EISNN/Archive/09230302_归档
# 2025-07-24 14:02:29.449 | INFO     | __main__:<module>:38 - ELE [077/218][127-5237]: D:/Baihm/EISNN/Archive/09230303_归档
# 2025-07-24 14:02:29.660 | INFO     | __main__:<module>:38 - ELE [078/218][127-5364]: D:/Baihm/EISNN/Archive/09230410_归档
# 2025-07-24 14:02:29.781 | INFO     | __main__:<module>:38 - ELE [079/218][82-5446]: D:/Baihm/EISNN/Archive/09230509_归档
# 2025-07-24 14:02:29.911 | INFO     | __main__:<module>:38 - ELE [080/218][121-5567]: D:/Baihm/EISNN/Archive/09230510_归档
# 2025-07-24 14:02:30.172 | INFO     | __main__:<module>:38 - ELE [081/218][126-5693]: D:/Baihm/EISNN/Archive/09230513_归档
# 2025-07-24 14:02:30.231 | INFO     | __main__:<module>:38 - ELE [082/218][32-5725]: D:/Baihm/EISNN/Archive/09230602_归档
# 2025-07-24 14:02:30.297 | INFO     | __main__:<module>:38 - ELE [083/218][45-5770]: D:/Baihm/EISNN/Archive/09230801_归档
# 2025-07-24 14:02:30.322 | INFO     | __main__:<module>:38 - ELE [084/218][4-5774]: D:/Baihm/EISNN/Archive/09231201_归档
# 2025-07-24 14:02:30.400 | INFO     | __main__:<module>:38 - ELE [085/218][67-5841]: D:/Baihm/EISNN/Archive/09231202_归档
# 2025-07-24 14:02:30.402 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231401_归档\Outlier_Ver04_DRTTik_Ver01\09231401_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.402 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231402_归档\Outlier_Ver04_DRTTik_Ver01\09231402_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.403 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231403_归档\Outlier_Ver04_DRTTik_Ver01\09231403_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.403 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231404_归档\Outlier_Ver04_DRTTik_Ver01\09231404_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.404 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231405_归档\Outlier_Ver04_DRTTik_Ver01\09231405_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.404 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231406_归档\Outlier_Ver04_DRTTik_Ver01\09231406_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.405 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231407_归档\Outlier_Ver04_DRTTik_Ver01\09231407_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.405 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/09231408_归档\Outlier_Ver04_DRTTik_Ver01\09231408_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:30.497 | INFO     | __main__:<module>:38 - ELE [094/218][102-5943]: D:/Baihm/EISNN/Archive/09231409_归档
# 2025-07-24 14:02:30.683 | INFO     | __main__:<module>:38 - ELE [095/218][126-6069]: D:/Baihm/EISNN/Archive/09250102_归档
# 2025-07-24 14:02:30.838 | INFO     | __main__:<module>:38 - ELE [096/218][123-6192]: D:/Baihm/EISNN/Archive/09250103_归档
# 2025-07-24 14:02:30.971 | INFO     | __main__:<module>:38 - ELE [097/218][116-6308]: D:/Baihm/EISNN/Archive/09250104_归档
# 2025-07-24 14:02:31.119 | INFO     | __main__:<module>:38 - ELE [098/218][128-6436]: D:/Baihm/EISNN/Archive/09250210_归档
# 2025-07-24 14:02:31.230 | INFO     | __main__:<module>:38 - ELE [099/218][123-6559]: D:/Baihm/EISNN/Archive/09290311_归档
# 2025-07-24 14:02:31.367 | INFO     | __main__:<module>:38 - ELE [100/218][128-6687]: D:/Baihm/EISNN/Archive/09290312_归档
# 2025-07-24 14:02:31.498 | INFO     | __main__:<module>:38 - ELE [101/218][124-6811]: D:/Baihm/EISNN/Archive/09290314_归档
# 2025-07-24 14:02:31.654 | INFO     | __main__:<module>:38 - ELE [102/218][128-6939]: D:/Baihm/EISNN/Archive/09290511_归档
# 2025-07-24 14:02:31.674 | INFO     | __main__:<module>:38 - ELE [103/218][6-6945]: D:/Baihm/EISNN/Archive/10017036_归档
# 2025-07-24 14:02:31.737 | INFO     | __main__:<module>:38 - ELE [104/218][64-7009]: D:/Baihm/EISNN/Archive/10017037_归档
# 2025-07-24 14:02:31.783 | INFO     | __main__:<module>:38 - ELE [105/218][25-7034]: D:/Baihm/EISNN/Archive/10017038_归档
# 2025-07-24 14:02:31.899 | INFO     | __main__:<module>:38 - ELE [106/218][68-7102]: D:/Baihm/EISNN/Archive/10037050_归档
# 2025-07-24 14:02:31.998 | INFO     | __main__:<module>:38 - ELE [107/218][68-7170]: D:/Baihm/EISNN/Archive/10037051_归档
# 2025-07-24 14:02:32.075 | INFO     | __main__:<module>:38 - ELE [108/218][62-7232]: D:/Baihm/EISNN/Archive/10037052_归档
# 2025-07-24 14:02:32.153 | INFO     | __main__:<module>:38 - ELE [109/218][63-7295]: D:/Baihm/EISNN/Archive/10047056_归档
# 2025-07-24 14:02:32.223 | INFO     | __main__:<module>:38 - ELE [110/218][56-7351]: D:/Baihm/EISNN/Archive/10047059_归档
# 2025-07-24 14:02:32.283 | INFO     | __main__:<module>:38 - ELE [111/218][49-7400]: D:/Baihm/EISNN/Archive/10047060_归档
# 2025-07-24 14:02:32.407 | INFO     | __main__:<module>:38 - ELE [112/218][67-7467]: D:/Baihm/EISNN/Archive/10057069_归档
# 2025-07-24 14:02:32.408 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/10057070_归档\Outlier_Ver04_DRTTik_Ver01\10057070_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:32.487 | INFO     | __main__:<module>:38 - ELE [114/218][66-7533]: D:/Baihm/EISNN/Archive/10057071_归档
# 2025-07-24 14:02:32.508 | INFO     | __main__:<module>:38 - ELE [115/218][9-7542]: D:/Baihm/EISNN/Archive/10057083_归档
# 2025-07-24 14:02:32.570 | INFO     | __main__:<module>:38 - ELE [116/218][61-7603]: D:/Baihm/EISNN/Archive/10057084_归档
# 2025-07-24 14:02:32.637 | INFO     | __main__:<module>:38 - ELE [117/218][68-7671]: D:/Baihm/EISNN/Archive/10057087_归档
# 2025-07-24 14:02:32.696 | INFO     | __main__:<module>:38 - ELE [118/218][36-7707]: D:/Baihm/EISNN/Archive/10067077_归档
# 2025-07-24 14:02:32.732 | INFO     | __main__:<module>:38 - ELE [119/218][11-7718]: D:/Baihm/EISNN/Archive/10067078_归档
# 2025-07-24 14:02:32.811 | INFO     | __main__:<module>:38 - ELE [120/218][63-7781]: D:/Baihm/EISNN/Archive/10067080_归档
# 2025-07-24 14:02:32.923 | INFO     | __main__:<module>:38 - ELE [121/218][110-7891]: D:/Baihm/EISNN/Archive/10080508_归档
# 2025-07-24 14:02:33.025 | INFO     | __main__:<module>:38 - ELE [122/218][123-8014]: D:/Baihm/EISNN/Archive/10080509_归档
# 2025-07-24 14:02:33.119 | INFO     | __main__:<module>:38 - ELE [123/218][95-8109]: D:/Baihm/EISNN/Archive/10080510_归档
# 2025-07-24 14:02:33.226 | INFO     | __main__:<module>:38 - ELE [124/218][115-8224]: D:/Baihm/EISNN/Archive/10080601_归档
# 2025-07-24 14:02:33.228 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/10080602_归档\Outlier_Ver04_DRTTik_Ver01\10080602_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:33.329 | INFO     | __main__:<module>:38 - ELE [126/218][123-8347]: D:/Baihm/EISNN/Archive/10080603_归档
# 2025-07-24 14:02:33.426 | INFO     | __main__:<module>:38 - ELE [127/218][123-8470]: D:/Baihm/EISNN/Archive/10080706_归档
# 2025-07-24 14:02:33.513 | INFO     | __main__:<module>:38 - ELE [128/218][125-8595]: D:/Baihm/EISNN/Archive/10080708_归档
# 2025-07-24 14:02:33.515 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/10086061_归档\Outlier_Ver04_DRTTik_Ver01\10086061_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:33.515 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/10086063_归档\Outlier_Ver04_DRTTik_Ver01\10086063_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:33.516 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/10086118_归档\Outlier_Ver04_DRTTik_Ver01\10086118_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:33.610 | INFO     | __main__:<module>:38 - ELE [132/218][82-8677]: D:/Baihm/EISNN/Archive/10150201_归档
# 2025-07-24 14:02:33.760 | INFO     | __main__:<module>:38 - ELE [133/218][120-8797]: D:/Baihm/EISNN/Archive/10150202_归档
# 2025-07-24 14:02:33.917 | INFO     | __main__:<module>:38 - ELE [134/218][123-8920]: D:/Baihm/EISNN/Archive/10150203_归档
# 2025-07-24 14:02:34.063 | INFO     | __main__:<module>:38 - ELE [135/218][126-9046]: D:/Baihm/EISNN/Archive/10160301_归档
# 2025-07-24 14:02:34.203 | INFO     | __main__:<module>:38 - ELE [136/218][124-9170]: D:/Baihm/EISNN/Archive/10160302_归档
# 2025-07-24 14:02:34.268 | INFO     | __main__:<module>:38 - ELE [137/218][11-9181]: D:/Baihm/EISNN/Archive/10160303_归档
# 2025-07-24 14:02:34.420 | INFO     | __main__:<module>:38 - ELE [138/218][126-9307]: D:/Baihm/EISNN/Archive/10210301_归档
# 2025-07-24 14:02:34.570 | INFO     | __main__:<module>:38 - ELE [139/218][123-9430]: D:/Baihm/EISNN/Archive/10210302_归档
# 2025-07-24 14:02:34.709 | INFO     | __main__:<module>:38 - ELE [140/218][120-9550]: D:/Baihm/EISNN/Archive/10210303_归档
# 2025-07-24 14:02:34.711 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11017483_归档\Outlier_Ver04_DRTTik_Ver01\11017483_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.711 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11017484_归档\Outlier_Ver04_DRTTik_Ver01\11017484_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.711 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11026042_归档\Outlier_Ver04_DRTTik_Ver01\11026042_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.712 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11026043_归档\Outlier_Ver04_DRTTik_Ver01\11026043_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.712 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11026044_归档\Outlier_Ver04_DRTTik_Ver01\11026044_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.843 | INFO     | __main__:<module>:38 - ELE [146/218][113-9663]: D:/Baihm/EISNN/Archive/11037454_归档
# 2025-07-24 14:02:34.845 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11037455_归档\Outlier_Ver04_DRTTik_Ver01\11037455_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.845 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11037456_归档\Outlier_Ver04_DRTTik_Ver01\11037456_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:34.956 | INFO     | __main__:<module>:38 - ELE [149/218][74-9737]: D:/Baihm/EISNN/Archive/11037715_归档
# 2025-07-24 14:02:35.060 | INFO     | __main__:<module>:38 - ELE [150/218][73-9810]: D:/Baihm/EISNN/Archive/11037716_归档
# 2025-07-24 14:02:35.149 | INFO     | __main__:<module>:38 - ELE [151/218][75-9885]: D:/Baihm/EISNN/Archive/11037717_归档
# 2025-07-24 14:02:35.246 | INFO     | __main__:<module>:38 - ELE [152/218][63-9948]: D:/Baihm/EISNN/Archive/11047722_归档
# 2025-07-24 14:02:35.340 | INFO     | __main__:<module>:38 - ELE [153/218][74-10022]: D:/Baihm/EISNN/Archive/11047725_归档
# 2025-07-24 14:02:35.436 | INFO     | __main__:<module>:38 - ELE [154/218][73-10095]: D:/Baihm/EISNN/Archive/11047726_归档
# 2025-07-24 14:02:35.496 | INFO     | __main__:<module>:38 - ELE [155/218][61-10156]: D:/Baihm/EISNN/Archive/11050201_归档
# 2025-07-24 14:02:35.522 | INFO     | __main__:<module>:38 - ELE [156/218][8-10164]: D:/Baihm/EISNN/Archive/11050202_归档
# 2025-07-24 14:02:35.592 | INFO     | __main__:<module>:38 - ELE [157/218][56-10220]: D:/Baihm/EISNN/Archive/11050203_归档
# 2025-07-24 14:02:35.713 | INFO     | __main__:<module>:38 - ELE [158/218][79-10299]: D:/Baihm/EISNN/Archive/11057709_归档
# 2025-07-24 14:02:35.817 | INFO     | __main__:<module>:38 - ELE [159/218][56-10355]: D:/Baihm/EISNN/Archive/11057710_归档
# 2025-07-24 14:02:35.991 | INFO     | __main__:<module>:38 - ELE [160/218][94-10449]: D:/Baihm/EISNN/Archive/11057712_归档
# 2025-07-24 14:02:35.993 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11057714_归档\Outlier_Ver04_DRTTik_Ver01\11057714_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.119 | INFO     | __main__:<module>:38 - ELE [162/218][70-10519]: D:/Baihm/EISNN/Archive/11067222_归档
# 2025-07-24 14:02:36.251 | INFO     | __main__:<module>:38 - ELE [163/218][75-10594]: D:/Baihm/EISNN/Archive/11067223_归档
# 2025-07-24 14:02:36.381 | INFO     | __main__:<module>:38 - ELE [164/218][74-10668]: D:/Baihm/EISNN/Archive/11067224_归档
# 2025-07-24 14:02:36.383 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11077496_归档\Outlier_Ver04_DRTTik_Ver01\11077496_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.384 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11077497_归档\Outlier_Ver04_DRTTik_Ver01\11077497_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.384 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11077498_归档\Outlier_Ver04_DRTTik_Ver01\11077498_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.385 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11207129_归档\Outlier_Ver04_DRTTik_Ver01\11207129_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.385 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11207147_归档\Outlier_Ver04_DRTTik_Ver01\11207147_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.385 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/11207149_归档\Outlier_Ver04_DRTTik_Ver01\11207149_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.386 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/12027309_归档\Outlier_Ver04_DRTTik_Ver01\12027309_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.386 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/12027320_归档\Outlier_Ver04_DRTTik_Ver01\12027320_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.387 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/12120001_归档\Outlier_Ver04_DRTTik_Ver01\12120001_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.387 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/12120101_归档\Outlier_Ver04_DRTTik_Ver01\12120101_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.388 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/12201111_归档\Outlier_Ver04_DRTTik_Ver01\12201111_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.388 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/15361101_归档\Outlier_Ver04_DRTTik_Ver01\15361101_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.389 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/15361102_归档\Outlier_Ver04_DRTTik_Ver01\15361102_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.391 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/15361104_归档\Outlier_Ver04_DRTTik_Ver01\15361104_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:36.456 | INFO     | __main__:<module>:38 - ELE [179/218][66-10734]: D:/Baihm/EISNN/Archive/16037225_归档
# 2025-07-24 14:02:36.535 | INFO     | __main__:<module>:38 - ELE [180/218][81-10815]: D:/Baihm/EISNN/Archive/16037226_归档
# 2025-07-24 14:02:36.620 | INFO     | __main__:<module>:38 - ELE [181/218][76-10891]: D:/Baihm/EISNN/Archive/16037227_归档
# 2025-07-24 14:02:36.690 | INFO     | __main__:<module>:38 - ELE [182/218][25-10916]: D:/Baihm/EISNN/Archive/20037515_归档
# 2025-07-24 14:02:36.755 | INFO     | __main__:<module>:38 - ELE [183/218][26-10942]: D:/Baihm/EISNN/Archive/20037516_归档
# 2025-07-24 14:02:36.814 | INFO     | __main__:<module>:38 - ELE [184/218][33-10975]: D:/Baihm/EISNN/Archive/20037517_归档
# 2025-07-24 14:02:36.892 | INFO     | __main__:<module>:38 - ELE [185/218][69-11044]: D:/Baihm/EISNN/Archive/20057520_归档
# 2025-07-24 14:02:36.996 | INFO     | __main__:<module>:38 - ELE [186/218][80-11124]: D:/Baihm/EISNN/Archive/20057521_归档
# 2025-07-24 14:02:37.071 | INFO     | __main__:<module>:38 - ELE [187/218][76-11200]: D:/Baihm/EISNN/Archive/20067523_归档
# 2025-07-24 14:02:37.149 | INFO     | __main__:<module>:38 - ELE [188/218][75-11275]: D:/Baihm/EISNN/Archive/20067524_归档
# 2025-07-24 14:02:37.257 | INFO     | __main__:<module>:38 - ELE [189/218][73-11348]: D:/Baihm/EISNN/Archive/20067525_归档
# 2025-07-24 14:02:37.315 | INFO     | __main__:<module>:38 - ELE [190/218][21-11369]: D:/Baihm/EISNN/Archive/22017367_归档
# 2025-07-24 14:02:37.316 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/22017368_归档\Outlier_Ver04_DRTTik_Ver01\22017368_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:37.371 | INFO     | __main__:<module>:38 - ELE [192/218][23-11392]: D:/Baihm/EISNN/Archive/22017369_归档
# 2025-07-24 14:02:37.476 | INFO     | __main__:<module>:38 - ELE [193/218][82-11474]: D:/Baihm/EISNN/Archive/22017370_归档
# 2025-07-24 14:02:37.519 | INFO     | __main__:<module>:38 - ELE [194/218][21-11495]: D:/Baihm/EISNN/Archive/22017371_归档
# 2025-07-24 14:02:37.611 | INFO     | __main__:<module>:38 - ELE [195/218][71-11566]: D:/Baihm/EISNN/Archive/22017372_归档
# 2025-07-24 14:02:37.612 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/22027364_归档\Outlier_Ver04_DRTTik_Ver01\22027364_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:37.673 | INFO     | __main__:<module>:38 - ELE [197/218][24-11590]: D:/Baihm/EISNN/Archive/22027365_归档
# 2025-07-24 14:02:37.705 | INFO     | __main__:<module>:38 - ELE [198/218][13-11603]: D:/Baihm/EISNN/Archive/22027366_归档
# 2025-07-24 14:02:37.750 | INFO     | __main__:<module>:38 - ELE [199/218][26-11629]: D:/Baihm/EISNN/Archive/22037378_归档
# 2025-07-24 14:02:37.812 | INFO     | __main__:<module>:38 - ELE [200/218][51-11680]: D:/Baihm/EISNN/Archive/22037379_归档
# 2025-07-24 14:02:37.913 | INFO     | __main__:<module>:38 - ELE [201/218][73-11753]: D:/Baihm/EISNN/Archive/22037380_归档
# 2025-07-24 14:02:37.962 | INFO     | __main__:<module>:38 - ELE [202/218][33-11786]: D:/Baihm/EISNN/Archive/22047374_归档
# 2025-07-24 14:02:38.022 | INFO     | __main__:<module>:38 - ELE [203/218][28-11814]: D:/Baihm/EISNN/Archive/22047376_归档
# 2025-07-24 14:02:38.092 | INFO     | __main__:<module>:38 - ELE [204/218][21-11835]: D:/Baihm/EISNN/Archive/22047377_归档
# 2025-07-24 14:02:38.094 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/23066051_归档\Outlier_Ver04_DRTTik_Ver01\23066051_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.095 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/23066053_归档\Outlier_Ver04_DRTTik_Ver01\23066053_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.096 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/23066054_归档\Outlier_Ver04_DRTTik_Ver01\23066054_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.097 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/23177394_归档\Outlier_Ver04_DRTTik_Ver01\23177394_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.098 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/23177395_归档\Outlier_Ver04_DRTTik_Ver01\23177395_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.206 | INFO     | __main__:<module>:38 - ELE [210/218][117-11952]: D:/Baihm/EISNN/Archive/23177396_归档
# 2025-07-24 14:02:38.208 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/24091971_归档\Outlier_Ver04_DRTTik_Ver01\24091971_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.209 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/24091972_归档\Outlier_Ver04_DRTTik_Ver01\24091972_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.209 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/24091981_归档\Outlier_Ver04_DRTTik_Ver01\24091981_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.209 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/24091982_归档\Outlier_Ver04_DRTTik_Ver01\24091982_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.210 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/29036055_归档\Outlier_Ver04_DRTTik_Ver01\29036055_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.210 | WARNING  | __main__:<module>:16 - D:/Baihm/EISNN/Archive/29036056_归档\Outlier_Ver04_DRTTik_Ver01\29036056_Outlier_Ver04_DRTTik_Ver01.pt does not exist
# 2025-07-24 14:02:38.325 | INFO     | __main__:<module>:38 - ELE [217/218][119-12071]: D:/Baihm/EISNN/Archive/29036057_归档
# 2025-07-24 14:02:38.327 | INFO     | __main__:<module>:73 - Total 12071 data points from 152 electrodes

# %% [markdown]
# ## Plot All Data

# %%
app = pg.mkQApp()
win = pg.GraphicsLayoutWidget(show=True, title="Big Line Plot")
plot = win.addPlot()
plot.setWindowTitle('2e7 Points Line')
plot.setAspectLocked(False)

# 加载和 flatten 数据（你已有这步）
x_list = []
y_list = []

for i in range(len(Loe_vitro0_start_list)):
    x = Loe_vitro0_start_list[i][1, :]
    y = Loe_vitro0_start_list[i][2, :]
    x_list.append(x)
    y_list.append(y)

x_all = np.concatenate(x_list).astype(np.float32)
y_all = np.concatenate(y_list).astype(np.float32)

# 做 log 变换（注意不加 setLogMode）
# x_log = np.log10(x_all)
# y_log = np.log10(y_all)

# x_log = np.log10(x_all) + np.log10(y_all)
# y_log = np.log10(x_all) - np.log10(y_all)
x_log = np.log10(x_all) + np.log10(y_all)
y_log = x_all/y_all

# 用 PlotDataItem 画线
line = pg.PlotDataItem(x=x_log, y=y_log, pen=pg.mkPen((255, 255, 255, 10), width=1))
plot.addItem(line)
