# %% [markdown]
# # Import
# * 增加了Bootstrapping，对充满非线性元件的神经界面来说很合适

# %%
import os
import re
import gc
import sys 
from datetime import datetime
from loguru import logger



import torch
import numpy as np
from scipy.linalg import eig, svd, solve
from statsmodels.nonparametric.smoothers_lowess import lowess


import matplotlib.pyplot as plt
# %matplotlib qt

# %% [markdown]
# # Loesner Framework

# %% [markdown]
# ## Definition

# %%
def Loewner_Framework(f, Z, REALFLAG = True):
    '''==================================================
        Construct Loewner Pencel
        Parameter: 
            f:          real array of frequency values
            Z:          complex array of impedance values (H = Z)
            REALFLAG:   boolean flag to indicate if the model should have real entries
        Returen:
            L:          Loewner matrix
            Ls:         Shifted Loewner matrix
            H_left:     Impedance values for group left
            H_right:    Impedance values for group right
        ==================================================
    '''
    _n = len(f)
    s = 2j * np.pi * f

    # Ensuring the input have an even number of elements 
    # for constructing the model having real entries
    if REALFLAG:
        if _n % 2 != 0:
            _n = _n - 1

    # Left & Right Data for Loewner Framework
    s_left  = s[:_n:2]
    H_left  = Z[:_n:2]
    s_right = s[1:_n:2] 
    H_right = Z[1:_n:2]

    # Construct complex conjugate values for ensuring model having real entries
    if REALFLAG:
        s_left  = np.stack([s_left, s_left.conj()], axis=1).flatten()
        H_left  = np.stack([H_left, H_left.conj()], axis=1).flatten()
        s_right = np.stack([s_right, s_right.conj()], axis=1).flatten()
        H_right = np.stack([H_right, H_right.conj()], axis=1).flatten()

    # Constructing the Loewner Matrix & Shifted Loewner Matrix
    # L   = (H_left[:,None] - H_right[None,:]) / (s_left[:,None] - s_right[None,:])
    # Ls  = (s_left[:,None] * H_left[:,None] - s_right[None,:] * H_right[None,:]) / (s_left[:,None] - s_right[None,:])
    L   = (H_left[None,:] - H_right[:,None]) / (s_left[None,:] - s_right[:,None])
    Ls  = (s_left[None,:] * H_left[None,:] - s_right[:,None] * H_right[:,None]) / (s_left[None,:] - s_right[:,None])

    # Transforming the conplex L & Ls to obtain matrices with real entries
    if REALFLAG:
        _J_diag = np.eye(_n//2)
        _J  = (1/np.sqrt(2)) * np.array([[1, 1j], [1, -1j]])
        _J  = np.kron(_J_diag, _J)

        L       = (_J.conj().T @ L @ _J).real
        Ls      = (_J.conj().T @ Ls @ _J).real
        H_left  = ((_J.T @ H_left).T).real
        H_right = (_J.conj().T @ H_right).real

        
    return L, Ls, H_left, H_right

def state_space_model(L, Ls, H_left, H_right):
    '''==================================================
        Construct state space model from Loewner Pencel
        Parameter: 
            L:          Loewner matrix
            Ls:         Shifted Loewner matrix
            H_left:     Impedance values for group left
            H_right:    Impedance values for group right
        Returen:
            Ek, Ak, Bk, Ck:
                Ek x' = Ak x + Bk u
                   y  = Ck x + Dk u (Dk = 0)
        ==================================================
    '''
    # rank of the Loewner Pencel
    _rank = np.linalg.matrix_rank(np.concatenate((L, Ls), axis=0))
    Y_L, svd_L, X_L = svd(L, full_matrices=False, lapack_driver='gesvd')
    X_L = X_L.T
    
    # Reduced state space model interpolating the data
    Yk = Y_L[:, :_rank]
    Xk = X_L[:, :_rank]

    Ek = -Yk.T@L@Xk
    Ak = -Yk.T@Ls@Xk
    Bk = Yk.T@H_right
    Ck = H_left.T@Xk

    return Ek, Ak, Bk, Ck

def DRT_Transform(Ek, Ak, Bk, Ck, REALFLAG = True, real_th = 1e3):
    '''==================================================
        Transform state space model to DRT model
        Parameter: 
            Ek, Ak, Bk, Ck:
                Ek x' = Ak x + Bk u
                   y  = Ck x + Dk u (Dk = 0)
        Returen:
            tau_i   tau_i from RC pair in DRT
            R_i:    R_i from RC pair in DRT
            C_i:    C_i from RC pair in DRT
        ==================================================
    '''
    # Solve Av= λEv & wT A= λ wT E & Res = CvwB/wEv, wEv =  δ
    _pol, _U = eig(Ak, Ek)     # 
    wB = solve(_U, solve(Ek,Bk))
    Cv = Ck @ _U
    _res = Cv * wB

    # Calculate R_i & tau_i
    tau_i   = (-1/_pol) 
    R_i     = (-_res / _pol)
    C_i     = (1/_res)

    if REALFLAG:
        real_ratio = np.where(np.abs(tau_i.imag) == 0, np.inf, np.abs(tau_i.real / (tau_i.imag+1e-20)))
        tau_i = np.abs(tau_i[real_ratio > real_th])
        R_i = np.abs(R_i[real_ratio > real_th])
        C_i = np.abs(C_i[real_ratio > real_th])


    return tau_i, R_i, C_i

def DRT_Reconstruction_SSM(Ek, Ak, Bk, Ck, f, Z):
    '''==================================================
        Reconstruct DRT from state space model
        Parameter: 
            R_i:    R_i from RC pair in DRT
            tau_i   tau_i from RC pair in DRT
            f:  real array of frequency values
            Z:  complex array of impedance values (H = Z)
        Returen:
            H:  reconstructed impedance values
        ==================================================
    '''
    s = 2j * np.pi * f
    H = np.array([Ck @ solve(si * Ek - Ak, Bk) for si in s])
    res_ReZ = np.abs(((Z.real - H.real) / np.abs(Z))) * 100
    res_ImZ = np.abs(((Z.imag - H.imag) / np.abs(Z))) * 100

    return H, res_ReZ, res_ImZ


def DRT_Reconstruction_DRT(R_i, tau_i, f, Z):
    '''==================================================
        Reconstruct DRT from state space model
        Parameter: 
            Ek, Ak, Bk, Ck:
                Ek x' = Ak x + Bk u
                   y  = Ck x + Dk u (Dk = 0)
            f:  real array of frequency values
            Z:  complex array of impedance values (H = Z)
        Returen:
            H:  reconstructed impedance values
        ==================================================
    '''
    s = 2j * np.pi * f  # Broadcasting tau_i to match f
    _RC = R_i[None, :] / (1+s[:,None] * tau_i[None,:])
    H = np.sum(_RC, axis=1)

    res_ReZ = np.abs(((Z.real - H.real) / np.abs(Z))) * 100
    res_ImZ = np.abs(((Z.imag - H.imag) / np.abs(Z))) * 100

    return H, res_ReZ, res_ImZ

def DRT_singularity_analysis(f, Z, REALFLAG = True):
    '''==================================================
        DRT Singularity Analysis
        Parameter: 
            f:          real array of frequency values
            Z:          complex array of impedance values (H = Z)
            REALFLAG:   boolean flag to indicate if the model should have real entries
        Returen:
            R_i:        R_i from RC pair in DRT
            tau_i:      tau_i from RC pair in DRT
        ==================================================
    '''
    L, Ls, H_left, H_right = Loewner_Framework(f, Z, REALFLAG)
    Y, svd_L, X = svd(np.concatenate([L, Ls]), full_matrices=False)

    return svd_L

def DRT_Calculation(f, Z, REALFLAG = True):
    '''==================================================
        DRT Analysis
        Parameter: 
            f:          real array of frequency values
            Z:          complex array of impedance values (H = Z)
            REALFLAG:   boolean flag to indicate if the model should have real entries
        Returen:
            R_i:        R_i from RC pair in DRT
            tau_i:      tau_i from RC pair in DRT
            H:          reconstructed impedance values
            res_ReZ:    relative error of real part of impedance values
            res_ImZ:    relative error of imaginary part of impedance values
        ==================================================
    '''
    L, Ls, H_left, H_right = Loewner_Framework(f, Z, REALFLAG)
    Ek, Ak, Bk, Ck = state_space_model(L, Ls, H_left, H_right)
    tau_i, R_i, C_i = DRT_Transform(Ek, Ak, Bk, Ck)

    return tau_i, R_i, C_i

def DRT_Bootstrap(f, Z, REALFLAG = True, n_batch = 100, n_point = 100, idx_base=1000):
    '''==================================================
        DRT Analysis with Bootstrap for one channel
        Parameter: 
            f:          frequency values with full range (5000)
            Z:          impedance values (H = Z)
            n_batch:    number of bootstrap samples
            n_point:    number of points for each sample
            REALFLAG:   boolean flag to indicate if the model should have real entries
        Returen:
            DRTdata:    list of tuples (tau_i, R_i, C_i) for each sample
            EISdata:    list of tuples (f, Z.real, Z.imag) for each sample
        ==================================================
    '''
    DRTdata = []
    EISdata = []
    for _ in range(n_batch):

        
        indices = np.arange(idx_base, f.shape[0])
        bins = np.array_split(indices, n_point)
        sampled_indices = [np.random.choice(bin, 1)[0] for bin in bins]
        
        f_sampled = f[sampled_indices]
        Z_sampled = Z[sampled_indices]

        _tau_i, _R_i, _C_i = DRT_Calculation(f_sampled, Z_sampled, REALFLAG)
        DRTdata.append((np.array([_tau_i, _R_i, _C_i])))
        EISdata.append((np.array([f_sampled, Z_sampled.real, Z_sampled.imag])))

    return DRTdata, EISdata

def DRT_Loess(DRTdata):
    '''==================================================
        DRT Analysis with Loess
        Parameter: 
            DRTdata:    list of tuples (tau_i, R_i, C_i) for each sample
        Returen:
            DRTdata_Loess:    Loess smoothed DRT data
        ==================================================
    '''

    # _tau_i  = np.concatenate([i[0,1:-1] for i in DRTdata])
    # _R_i    = np.concatenate([i[1,1:-1] for i in DRTdata])
    # _C_i    = np.concatenate([i[2,1:-1] for i in DRTdata])
    _tau_i  = np.concatenate([i[0,:] for i in DRTdata])
    _R_i    = np.concatenate([i[1,:] for i in DRTdata])
    _C_i    = np.concatenate([i[2,:] for i in DRTdata])

    # _order  = _tau_i.argsort()
    # _tau_i  = _tau_i[_order]
    # _R_i    = _R_i[_order]
    # _C_i    = _C_i[_order]

    x_log = np.log(_tau_i)
    y_log = np.log(_R_i)-np.log(_C_i)
    
    y_log_smooth = lowess(y_log, x_log, frac=0.05, it=3, return_sorted=False)


    RC_loess         = np.exp(y_log_smooth)
    tau_loess       = _tau_i
    DRTdata_Loess   =  np.array([tau_loess, RC_loess])

    return DRTdata_Loess

# def DRT_Analysis_Batch(chData, REALFLAG = True):
#     '''==================================================
#         DRT Analysis for Batch Data - without eis_seq filtering
#         Parameter: 
#             chData:     list of tuples (f, Z) for each channel
#             REALFLAG:   boolean flag to indicate if the model should have real entries
#         Returen:
#             results:    list of tuples (R_i, C_i, tau_i, H, res_ReZ, res_ImZ) for each channel
#         ==================================================
#     '''
#     DRTdata_list = []
#     EISdata_list = []
#     Loess_list = []
#     f = chData[0,0,:]
#     for i in range(chData.shape[0]):
#         _Z = chData[i,1,:] + 1j*chData[i,2,:]
#         DRTdata, EISdata = DRT_Bootstrap(f, _Z, REALFLAG=REALFLAG, n_batch=n_batch, n_point=n_point, idx_base=idx_base)
#         DRTdata_Loess = DRT_Loess(DRTdata)

#         DRTdata_list.append(DRTdata)
#         EISdata_list.append(EISdata)
#         Loess_list.append(DRTdata_Loess)

#     return DRTdata_list, EISdata_list, Loess_list


def DRT_Plot_Batch(fig, DRTdata_list, EISdata_list, Loess_list, eis_seq):
    
    axis = [0] * 6
    axis[0] = fig.add_subplot(2,3,1)    # Nyquist Plot
    axis[1] = fig.add_subplot(2,3,2)    # Bode Plot (Magnitude)
    axis[2] = fig.add_subplot(2,3,3)    # Bode Plot (Phase)
    axis[3] = fig.add_subplot(2,3,4)    # Text
    axis[4] = fig.add_subplot(2,3,5)    # DRT (RC)
    axis[5] = fig.add_subplot(2,3,6)    # DRT (Rτ)


    text_axis = axis[3]
    text_axis.axis('off')

    _s       = 2
    _alpha   = 0.7

    cmap = plt.colormaps.get_cmap('rainbow_r')
    for i in range(len(EISdata_list)):
        if i in eis_seq:
            ch_eis      = EISdata_list[i][0]
            ch_drt      = DRTdata_list[i]
            ch_loess    = Loess_list[i]

            # ch_R    = np.array([i[1:,0] for i in ch_drt])
            # ch_C    = np.array([i[1:,-1] for i in ch_drt])
            ch_R    = np.concatenate([i[1,:] for i in ch_drt])
            ch_C    = np.concatenate([i[2,:] for i in ch_drt])

            _color  = cmap(i/len(EISdata_list))

            axis[0].plot(ch_eis[1,:], -ch_eis[2,:], color = _color, linewidth=2)
            axis[1].loglog(ch_eis[0,:], np.abs(ch_eis[1,:]+1j*ch_eis[2,:]), color = _color, linewidth=2)
            axis[2].semilogx(ch_eis[0,:], np.rad2deg(np.angle(ch_eis[1,:]+1j*ch_eis[2,:])), color = _color, linewidth=2)

            axis[4].scatter(ch_R, ch_C, s=_s, alpha=_alpha, color=_color, label=f'ch[{i:03d}]')
            axis[5].scatter(ch_loess[0,:], ch_loess[1,:], s=_s, alpha=_alpha, color=_color, label=f'ch[{i:03d}]')



    axis[0].set_aspect('equal', adjustable='datalim')
    axis[4].set_xscale('log')
    axis[4].set_yscale('log')
    axis[5].set_xscale('log')
    axis[5].set_yscale('log')


    return text_axis

# %% [markdown]
# ## Simulation Data

# %% [markdown]
# ### R-(R||C)-(R||C)

# %%
# R-(R||C)-(R||C)
# Element
R1 = 200; # Ω
R2 = 100; # Ω
R0 = 70;  # Ω

C1 = 2.5e-3; # 
C2 = 1e-4;   # 

# tau1 = R1*C1;  # s
# tau2 = R2*C2;  # s

f = np.logspace(-2,2,41);  # Hz

# Calculation of the impedance dataset 
Z_sim = np.array([1/((1/R1)+1j*w*C1) +1/((1/R2)+1j*w*C2) +R0 for w in 2*np.pi*f])
Z_sim_noise = Z_sim + np.random.normal(0, 0.001, Z_sim.shape) * Z_sim

# %% [markdown]
# ### Randle

# %%
# R0 = 70

# R1 = 10000 
# C1 = 2.5e-9

# Y1 = 1e-5 
 
# n1 = 0.66
# f = np.logspace(-1,5,61);  # Hz 

# Q1 = lambda x: 1/(Y1*(1j*x)**n1)
# Z_sim = np.array([ R0 + (R1+Q1(w))/(1+1j*w*C1*(R1+Q1(w))) for w in 2*np.pi*f])
# Z_sim_noise = Z_sim + np.random.normal(0, 0.01, Z_sim.shape) * Z_sim

# %% [markdown]
# ### Run LF

# %%
R_i, C_i, tau_i = DRT_Calculation(f, Z_sim, REALFLAG=True)
svd_L = DRT_singularity_analysis(f, Z_sim, REALFLAG=True)



# R_n, C_n, tau_n, H_n, res_ReZ_n, res_ImZ_n = DRT_Analysis_Single(f, Z_sim_noise, REALFLAG=True)
# svd_L_n = DRT_singularity_analysis(f, Z_sim_noise, REALFLAG=True)

# %% [markdown]
# ### Plot

# %%
# Z_plot = Z_sim
# H_plot = H
# R_plot = R_i
# C_plot = C_i
# tau_plot = tau_i
# res_ReZ_plot = res_ReZ
# res_ImZ_plot = res_ImZ
# svd_L_plot = svd_L
# DRT_Single_Plot(f, Z_plot, H_plot, R_plot, C_plot, tau_plot, res_ReZ_plot, res_ImZ_plot, svd_L_plot)

# %%
# Z_plot = Z_sim_noise
# H_plot = H_n
# R_plot = R_n
# C_plot = C_n
# tau_plot = tau_n
# res_ReZ_plot = res_ReZ_n
# res_ImZ_plot = res_ImZ_n
# svd_L_plot = svd_L_n
# DRT_Single_Plot(f, Z_plot, H_plot, R_plot, C_plot, tau_plot, res_ReZ_plot, res_ImZ_plot, svd_L_plot)

# %%
# tau_r = np.abs(tau_n.real / tau_n.imag)
# plt.figure()
# ax1 = plt.subplot(211)
# ax1.loglog(tau_i, R_i, 'o', label='R_i')
# ax1.loglog(tau_n[tau_r>1].real, R_n[tau_r>1].real, '*', label='R_n')
# ax1.legend()

# ax2 = plt.subplot(212)  
# ax2.loglog(tau_i, C_i, 'ro', label='C_i')
# ax2.loglog(tau_n[tau_r>1], C_n[tau_r>1], '*', label='C_n')
# ax2.legend()

# %% [markdown]
# # Data Loader

# %% [markdown]
# ## Definition

# %%
def SearchELE(rootPath, ele_pattern = re.compile(r"(.+?)_归档")):
    '''==================================================
        Search all electrode directories in the rootPath
        Parameter: 
            rootPath: current search path
            ele_pattern: electrode dir name patten
        Returen:
            ele_list: list of electrode directories
        ==================================================
    '''
    ele_list = []
    for i in os.listdir(rootPath):
        _path = os.path.join(rootPath, i)
        if os.path.isdir(_path):
            match_ele = ele_pattern.match(i)
            if match_ele:
                ele_list.append([_path, match_ele.group(1)])
            else:
                ele_list.extend(SearchELE(_path, ele_pattern))

    return ele_list

# %%
def setup_logger(log_dir="./LOG", log_filename="file.log", file_level="WARNING", console_level="WARNING"):
    # 创建目录
    os.makedirs(log_dir, exist_ok=True)
    log_fd = os.path.join(log_dir, log_filename)

    logger.remove()
    # 如果已有日志文件，重命名添加时间戳
    if os.path.exists(log_fd):
        name, ext = os.path.splitext(log_filename)
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        archived_name = f"{name}_{timestamp}{ext}"
        archived_path = os.path.join(log_dir, archived_name)
        os.rename(log_fd, archived_path)

    # 添加终端输出
    logger.add(sys.stdout, level=console_level, enqueue=True)

    # 添加文件输出
    logger.add(log_fd, level=file_level, encoding="utf-8", enqueue=True)

    return logger

# %% [markdown]
# ## Run

# %%
if True:
    setup_logger(log_dir="D:\Baihm\EISNN\LOG\DRT_Process_Log")

# logger.remove()
# logger.add(sys.stdout, level="WARNING")
# logger.add("./LOG/file.log", rotation="10 MB", level="INFO")
# Out:
# 2025-07-20 23:52:42.350 | WARNING  | __main__:<module>:30 - ELE[1/5]: 	S5877 - D:/Baihm/EISNN/Invivo\S5877_Ver02
# 2025-07-20 23:52:42.352 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[000] Begin
# 2025-07-20 23:53:12.263 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[001] Begin
# 2025-07-20 23:53:38.649 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[002] Begin
# 2025-07-20 23:54:08.599 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[003] Begin
# 2025-07-20 23:54:31.720 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[004] Begin
# 2025-07-20 23:54:51.901 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[005] Begin
# 2025-07-20 23:55:10.638 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[006] Begin
# 2025-07-20 23:55:34.258 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[007] Begin
# 2025-07-20 23:55:59.990 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[008] Begin
# 2025-07-20 23:56:25.462 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[009] Begin
# 2025-07-20 23:56:42.837 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[010] Begin
# 2025-07-20 23:57:01.782 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[011] Begin
# 2025-07-20 23:57:26.280 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[012] Begin
# 2025-07-20 23:57:46.825 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[013] Begin
# 2025-07-20 23:58:08.379 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[014] Begin
# 2025-07-20 23:58:27.104 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[015] Begin
# 2025-07-20 23:58:53.312 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[016] Begin
# 2025-07-20 23:59:19.173 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[017] Begin
# 2025-07-20 23:59:47.839 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[018] Begin
# 2025-07-21 00:00:15.118 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[019] Begin
# 2025-07-21 00:00:38.035 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[020] Begin
# 2025-07-21 00:01:04.187 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[021] Begin
# 2025-07-21 00:01:26.656 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[022] Begin
# 2025-07-21 00:01:51.126 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[023] Begin
# 2025-07-21 00:02:11.786 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[024] Begin
# 2025-07-21 00:02:35.990 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[025] Begin
# 2025-07-21 00:03:01.220 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[026] Begin
# 2025-07-21 00:03:26.678 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[027] Begin
# 2025-07-21 00:03:49.831 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[028] Begin
# 2025-07-21 00:04:15.807 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[029] Begin
# 2025-07-21 00:04:39.782 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[030] Begin
# 2025-07-21 00:05:05.493 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[031] Begin
# 2025-07-21 00:05:27.379 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[032] Begin
# 2025-07-21 00:05:43.186 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[033] Begin
# 2025-07-21 00:06:08.812 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[034] Begin
# 2025-07-21 00:06:35.227 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[035] Begin
# 2025-07-21 00:06:53.787 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[036] Begin
# 2025-07-21 00:07:21.070 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[037] Begin
# 2025-07-21 00:07:48.410 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[038] Begin
# 2025-07-21 00:08:10.822 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[039] Begin
# 2025-07-21 00:08:36.828 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[040] Begin
# 2025-07-21 00:09:03.276 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[041] Begin
# 2025-07-21 00:09:30.280 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[042] Begin
# 2025-07-21 00:09:57.509 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[043] Begin
# 2025-07-21 00:10:23.055 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[044] Begin
# 2025-07-21 00:10:50.192 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[045] Begin
# 2025-07-21 00:11:18.371 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[046] Begin
# 2025-07-21 00:11:44.309 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[047] Begin
# 2025-07-21 00:12:11.719 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[048] Begin
# 2025-07-21 00:12:38.328 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[049] Begin
# 2025-07-21 00:13:02.584 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[050] Begin
# 2025-07-21 00:13:23.896 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[051] Begin
# 2025-07-21 00:13:49.548 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[052] Begin
# 2025-07-21 00:14:09.575 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[053] Begin
# 2025-07-21 00:14:31.010 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[054] Begin
# 2025-07-21 00:14:55.465 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[055] Begin
# 2025-07-21 00:15:20.497 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[056] Begin
# 2025-07-21 00:15:47.406 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[057] Begin
# 2025-07-21 00:16:09.938 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[058] Begin
# 2025-07-21 00:16:30.297 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[059] Begin
# 2025-07-21 00:16:55.566 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[060] Begin
# 2025-07-21 00:17:17.382 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[061] Begin
# 2025-07-21 00:17:39.110 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[062] Begin
# 2025-07-21 00:18:07.369 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[063] Begin
# 2025-07-21 00:18:25.975 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[064] Begin
# 2025-07-21 00:18:47.828 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[065] Begin
# 2025-07-21 00:19:09.087 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[066] Begin
# 2025-07-21 00:19:28.687 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[067] Begin
# 2025-07-21 00:19:54.828 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[068] Begin
# 2025-07-21 00:20:19.485 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[069] Begin
# 2025-07-21 00:20:40.978 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[070] Begin
# 2025-07-21 00:21:01.371 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[071] Begin
# 2025-07-21 00:21:24.230 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[072] Begin
# 2025-07-21 00:21:50.074 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[073] Begin
# 2025-07-21 00:22:12.619 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[074] Begin
# 2025-07-21 00:22:35.526 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[075] Begin
# 2025-07-21 00:22:46.848 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[076] Begin
# 2025-07-21 00:23:09.148 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[077] Begin
# 2025-07-21 00:23:27.163 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[078] Begin
# 2025-07-21 00:23:44.254 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[079] Begin
# 2025-07-21 00:24:06.638 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[080] Begin
# 2025-07-21 00:24:28.420 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[081] Begin
# 2025-07-21 00:24:48.365 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[082] Begin
# 2025-07-21 00:25:11.104 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[083] Begin
# 2025-07-21 00:25:29.794 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[084] Begin
# 2025-07-21 00:25:49.889 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[085] Begin
# 2025-07-21 00:26:12.019 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[086] Begin
# 2025-07-21 00:26:36.857 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[087] Begin
# 2025-07-21 00:27:01.000 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[088] Begin
# 2025-07-21 00:27:21.315 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[089] Begin
# 2025-07-21 00:27:42.715 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[090] Begin
# 2025-07-21 00:28:01.491 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[091] Begin
# 2025-07-21 00:28:25.337 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[092] Begin
# 2025-07-21 00:28:47.190 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[093] Begin
# 2025-07-21 00:29:07.260 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[094] Begin
# 2025-07-21 00:29:31.097 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[095] Begin
# 2025-07-21 00:29:51.716 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[096] Begin
# 2025-07-21 00:30:16.068 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[097] Begin
# 2025-07-21 00:30:39.340 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[098] Begin
# 2025-07-21 00:31:03.504 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[099] Begin
# 2025-07-21 00:31:24.714 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[100] Begin
# 2025-07-21 00:31:50.079 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[101] Begin
# 2025-07-21 00:32:08.608 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[102] Begin
# 2025-07-21 00:32:35.289 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[103] Begin
# 2025-07-21 00:32:58.939 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[104] Begin
# 2025-07-21 00:33:22.718 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[105] Begin
# 2025-07-21 00:33:45.640 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[106] Begin
# 2025-07-21 00:34:08.517 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[107] Begin
# 2025-07-21 00:34:32.883 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[108] Begin
# 2025-07-21 00:34:58.722 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[109] Begin
# 2025-07-21 00:35:25.659 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[110] Begin
# 2025-07-21 00:35:52.351 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[111] Begin
# 2025-07-21 00:36:13.967 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[112] Begin
# 2025-07-21 00:36:33.971 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[113] Begin
# 2025-07-21 00:36:57.222 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[114] Begin
# 2025-07-21 00:37:21.706 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[115] Begin
# 2025-07-21 00:37:40.291 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[116] Begin
# 2025-07-21 00:38:04.694 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[117] Begin
# 2025-07-21 00:38:25.066 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[118] Begin
# 2025-07-21 00:38:43.738 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[119] Begin
# 2025-07-21 00:39:05.855 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[120] Begin
# 2025-07-21 00:39:33.079 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[121] Begin
# 2025-07-21 00:39:57.393 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[122] Begin
# 2025-07-21 00:40:14.252 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[123] Begin
# 2025-07-21 00:40:34.385 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[124] Begin
# 2025-07-21 00:40:57.402 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[125] Begin
# 2025-07-21 00:41:21.151 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[126] Begin
# 2025-07-21 00:41:44.189 | WARNING  | __main__:<module>:46 - ELE[S5877] - ch[127] Begin
# 2025-07-21 00:42:31.165 | WARNING  | __main__:<module>:30 - ELE[2/5]: 	S6005 - D:/Baihm/EISNN/Invivo\S6005_Ver02
# 2025-07-21 00:42:31.166 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[000] Begin
# 2025-07-21 00:42:51.959 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[001] Begin
# 2025-07-21 00:43:12.217 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[002] Begin
# 2025-07-21 00:43:32.536 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[003] Begin
# 2025-07-21 00:43:52.811 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[004] Begin
# 2025-07-21 00:44:10.625 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[005] Begin
# 2025-07-21 00:44:32.259 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[006] Begin
# 2025-07-21 00:44:52.458 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[007] Begin
# 2025-07-21 00:45:16.066 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[008] Begin
# 2025-07-21 00:45:36.435 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[009] Begin
# 2025-07-21 00:45:52.474 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[010] Begin
# 2025-07-21 00:46:09.181 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[011] Begin
# 2025-07-21 00:46:31.963 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[012] Begin
# 2025-07-21 00:46:53.872 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[013] Begin
# 2025-07-21 00:47:19.638 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[014] Begin
# 2025-07-21 00:47:34.450 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[015] Begin
# 2025-07-21 00:47:51.573 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[016] Begin
# 2025-07-21 00:48:11.676 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[017] Begin
# 2025-07-21 00:48:32.286 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[018] Begin
# 2025-07-21 00:48:52.306 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[019] Begin
# 2025-07-21 00:49:08.508 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[020] Begin
# 2025-07-21 00:49:23.307 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[021] Begin
# 2025-07-21 00:49:42.293 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[022] Begin
# 2025-07-21 00:50:02.332 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[023] Begin
# 2025-07-21 00:50:26.152 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[024] Begin
# 2025-07-21 00:50:47.571 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[025] Begin
# 2025-07-21 00:51:08.913 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[026] Begin
# 2025-07-21 00:51:23.501 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[027] Begin
# 2025-07-21 00:51:36.889 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[028] Begin
# 2025-07-21 00:51:50.187 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[029] Begin
# 2025-07-21 00:52:07.608 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[030] Begin
# 2025-07-21 00:52:29.158 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[031] Begin
# 2025-07-21 00:52:50.716 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[032] Begin
# 2025-07-21 00:53:12.219 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[033] Begin
# 2025-07-21 00:53:27.797 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[034] Begin
# 2025-07-21 00:53:48.185 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[035] Begin
# 2025-07-21 00:54:07.807 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[036] Begin
# 2025-07-21 00:54:29.401 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[037] Begin
# 2025-07-21 00:54:47.011 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[038] Begin
# 2025-07-21 00:55:06.140 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[039] Begin
# 2025-07-21 00:55:23.352 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[040] Begin
# 2025-07-21 00:55:43.125 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[041] Begin
# 2025-07-21 00:56:00.484 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[042] Begin
# 2025-07-21 00:56:19.432 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[043] Begin
# 2025-07-21 00:56:39.143 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[044] Begin
# 2025-07-21 00:56:56.792 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[045] Begin
# 2025-07-21 00:57:18.549 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[046] Begin
# 2025-07-21 00:57:37.282 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[047] Begin
# 2025-07-21 00:58:00.688 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[048] Begin
# 2025-07-21 00:58:18.694 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[049] Begin
# 2025-07-21 00:58:39.001 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[050] Begin
# 2025-07-21 00:58:57.676 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[051] Begin
# 2025-07-21 00:59:17.971 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[052] Begin
# 2025-07-21 00:59:38.100 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[053] Begin
# 2025-07-21 00:59:58.321 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[054] Begin
# 2025-07-21 01:00:15.800 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[055] Begin
# 2025-07-21 01:00:38.922 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[056] Begin
# 2025-07-21 01:01:00.274 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[057] Begin
# 2025-07-21 01:01:25.810 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[058] Begin
# 2025-07-21 01:01:44.623 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[059] Begin
# 2025-07-21 01:02:04.587 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[060] Begin
# 2025-07-21 01:02:24.561 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[061] Begin
# 2025-07-21 01:02:45.135 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[062] Begin
# 2025-07-21 01:03:06.713 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[063] Begin
# 2025-07-21 01:03:28.467 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[064] Begin
# 2025-07-21 01:03:51.492 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[065] Begin
# 2025-07-21 01:04:11.645 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[066] Begin
# 2025-07-21 01:04:36.028 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[067] Begin
# 2025-07-21 01:04:56.563 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[068] Begin
# 2025-07-21 01:05:19.277 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[069] Begin
# 2025-07-21 01:05:46.402 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[070] Begin
# 2025-07-21 01:06:05.468 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[071] Begin
# 2025-07-21 01:06:28.760 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[072] Begin
# 2025-07-21 01:06:40.226 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[073] Begin
# 2025-07-21 01:06:56.295 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[074] Begin
# 2025-07-21 01:07:22.407 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[075] Begin
# 2025-07-21 01:07:46.389 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[076] Begin
# 2025-07-21 01:08:05.007 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[077] Begin
# 2025-07-21 01:08:21.976 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[078] Begin
# 2025-07-21 01:08:43.304 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[079] Begin
# 2025-07-21 01:09:06.340 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[080] Begin
# 2025-07-21 01:09:29.524 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[081] Begin
# 2025-07-21 01:09:49.488 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[082] Begin
# 2025-07-21 01:10:11.826 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[083] Begin
# 2025-07-21 01:10:35.528 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[084] Begin
# 2025-07-21 01:10:50.073 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[085] Begin
# 2025-07-21 01:11:10.191 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[086] Begin
# 2025-07-21 01:11:31.978 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[087] Begin
# 2025-07-21 01:11:57.015 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[088] Begin
# 2025-07-21 01:12:14.401 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[089] Begin
# 2025-07-21 01:12:37.420 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[090] Begin
# 2025-07-21 01:12:57.521 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[091] Begin
# 2025-07-21 01:13:21.353 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[092] Begin
# 2025-07-21 01:13:43.163 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[093] Begin
# 2025-07-21 01:14:06.325 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[094] Begin
# 2025-07-21 01:14:26.726 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[095] Begin
# 2025-07-21 01:14:42.705 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[096] Begin
# 2025-07-21 01:15:04.776 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[097] Begin
# 2025-07-21 01:15:19.174 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[098] Begin
# 2025-07-21 01:15:40.432 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[099] Begin
# 2025-07-21 01:16:02.153 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[100] Begin
# 2025-07-21 01:16:19.599 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[101] Begin
# 2025-07-21 01:16:41.216 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[102] Begin
# 2025-07-21 01:17:00.860 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[103] Begin
# 2025-07-21 01:17:19.536 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[104] Begin
# 2025-07-21 01:17:40.831 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[105] Begin
# 2025-07-21 01:17:59.811 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[106] Begin
# 2025-07-21 01:18:21.435 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[107] Begin
# 2025-07-21 01:18:45.499 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[108] Begin
# 2025-07-21 01:19:05.726 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[109] Begin
# 2025-07-21 01:19:27.310 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[110] Begin
# 2025-07-21 01:19:50.362 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[111] Begin
# 2025-07-21 01:20:04.799 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[112] Begin
# 2025-07-21 01:20:28.275 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[113] Begin
# 2025-07-21 01:20:48.537 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[114] Begin
# 2025-07-21 01:21:06.745 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[115] Begin
# 2025-07-21 01:21:30.209 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[116] Begin
# 2025-07-21 01:21:52.979 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[117] Begin
# 2025-07-21 01:22:10.229 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[118] Begin
# 2025-07-21 01:22:30.785 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[119] Begin
# 2025-07-21 01:22:48.209 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[120] Begin
# 2025-07-21 01:23:08.341 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[121] Begin
# 2025-07-21 01:23:31.039 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[122] Begin
# 2025-07-21 01:23:49.012 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[123] Begin
# 2025-07-21 01:24:09.798 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[124] Begin
# 2025-07-21 01:24:33.019 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[125] Begin
# 2025-07-21 01:24:53.661 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[126] Begin
# 2025-07-21 01:25:12.657 | WARNING  | __main__:<module>:46 - ELE[S6005] - ch[127] Begin
# 2025-07-21 01:25:57.952 | WARNING  | __main__:<module>:30 - ELE[3/5]: 	S6006 - D:/Baihm/EISNN/Invivo\S6006_Ver02
# 2025-07-21 01:25:57.953 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[000] Begin
# 2025-07-21 01:26:21.022 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[001] Begin
# 2025-07-21 01:26:38.745 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[002] Begin
# 2025-07-21 01:26:58.098 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[003] Begin
# 2025-07-21 01:27:22.259 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[004] Begin
# 2025-07-21 01:27:41.271 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[005] Begin
# 2025-07-21 01:28:00.659 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[006] Begin
# 2025-07-21 01:28:23.551 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[007] Begin
# 2025-07-21 01:28:46.651 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[008] Begin
# 2025-07-21 01:29:09.835 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[009] Begin
# 2025-07-21 01:29:35.540 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[010] Begin
# 2025-07-21 01:30:01.513 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[011] Begin
# 2025-07-21 01:30:25.137 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[012] Begin
# 2025-07-21 01:30:47.989 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[013] Begin
# 2025-07-21 01:31:06.920 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[014] Begin
# 2025-07-21 01:31:26.376 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[015] Begin
# 2025-07-21 01:31:44.043 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[016] Begin
# 2025-07-21 01:32:02.921 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[017] Begin
# 2025-07-21 01:32:20.218 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[018] Begin
# 2025-07-21 01:32:34.904 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[019] Begin
# 2025-07-21 01:32:59.256 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[020] Begin
# 2025-07-21 01:33:20.670 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[021] Begin
# 2025-07-21 01:33:39.901 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[022] Begin
# 2025-07-21 01:33:59.997 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[023] Begin
# 2025-07-21 01:34:20.249 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[024] Begin
# 2025-07-21 01:34:42.533 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[025] Begin
# 2025-07-21 01:35:02.507 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[026] Begin
# 2025-07-21 01:35:15.955 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[027] Begin
# 2025-07-21 01:35:34.900 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[028] Begin
# 2025-07-21 01:35:55.782 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[029] Begin
# 2025-07-21 01:36:17.150 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[030] Begin
# 2025-07-21 01:36:39.813 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[031] Begin
# 2025-07-21 01:37:04.496 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[032] Begin
# 2025-07-21 01:37:24.759 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[033] Begin
# 2025-07-21 01:37:44.855 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[034] Begin
# 2025-07-21 01:38:05.434 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[035] Begin
# 2025-07-21 01:38:22.925 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[036] Begin
# 2025-07-21 01:38:40.606 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[037] Begin
# 2025-07-21 01:39:02.940 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[038] Begin
# 2025-07-21 01:39:26.977 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[039] Begin
# 2025-07-21 01:39:49.675 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[040] Begin
# 2025-07-21 01:40:13.341 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[041] Begin
# 2025-07-21 01:40:36.121 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[042] Begin
# 2025-07-21 01:40:56.503 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[043] Begin
# 2025-07-21 01:41:19.952 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[044] Begin
# 2025-07-21 01:41:40.545 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[045] Begin
# 2025-07-21 01:42:00.768 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[046] Begin
# 2025-07-21 01:42:26.882 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[047] Begin
# 2025-07-21 01:42:50.706 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[048] Begin
# 2025-07-21 01:43:14.999 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[049] Begin
# 2025-07-21 01:43:39.973 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[050] Begin
# 2025-07-21 01:44:01.341 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[051] Begin
# 2025-07-21 01:44:15.848 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[052] Begin
# 2025-07-21 01:44:39.585 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[053] Begin
# 2025-07-21 01:44:55.325 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[054] Begin
# 2025-07-21 01:45:20.996 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[055] Begin
# 2025-07-21 01:45:41.643 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[056] Begin
# 2025-07-21 01:45:53.464 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[057] Begin
# 2025-07-21 01:46:16.066 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[058] Begin
# 2025-07-21 01:46:43.719 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[059] Begin
# 2025-07-21 01:47:00.636 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[060] Begin
# 2025-07-21 01:47:22.004 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[061] Begin
# 2025-07-21 01:47:43.859 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[062] Begin
# 2025-07-21 01:48:07.149 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[063] Begin
# 2025-07-21 01:48:26.294 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[064] Begin
# 2025-07-21 01:48:44.130 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[065] Begin
# 2025-07-21 01:49:07.277 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[066] Begin
# 2025-07-21 01:49:30.695 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[067] Begin
# 2025-07-21 01:49:49.577 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[068] Begin
# 2025-07-21 01:50:05.545 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[069] Begin
# 2025-07-21 01:50:18.646 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[070] Begin
# 2025-07-21 01:50:41.335 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[071] Begin
# 2025-07-21 01:51:10.373 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[072] Begin
# 2025-07-21 01:51:23.413 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[073] Begin
# 2025-07-21 01:51:43.668 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[074] Begin
# 2025-07-21 01:52:05.093 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[075] Begin
# 2025-07-21 01:52:20.075 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[076] Begin
# 2025-07-21 01:52:44.626 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[077] Begin
# 2025-07-21 01:53:03.228 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[078] Begin
# 2025-07-21 01:53:19.321 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[079] Begin
# 2025-07-21 01:53:41.325 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[080] Begin
# 2025-07-21 01:53:58.914 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[081] Begin
# 2025-07-21 01:54:22.076 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[082] Begin
# 2025-07-21 01:54:44.480 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[083] Begin
# 2025-07-21 01:55:07.671 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[084] Begin
# 2025-07-21 01:55:28.840 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[085] Begin
# 2025-07-21 01:55:47.812 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[086] Begin
# 2025-07-21 01:56:07.681 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[087] Begin
# 2025-07-21 01:56:23.434 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[088] Begin
# 2025-07-21 01:56:48.161 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[089] Begin
# 2025-07-21 01:57:11.729 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[090] Begin
# 2025-07-21 01:57:27.697 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[091] Begin
# 2025-07-21 01:57:50.687 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[092] Begin
# 2025-07-21 01:58:12.156 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[093] Begin
# 2025-07-21 01:58:30.155 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[094] Begin
# 2025-07-21 01:58:50.594 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[095] Begin
# 2025-07-21 01:59:12.254 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[096] Begin
# 2025-07-21 01:59:30.562 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[097] Begin
# 2025-07-21 01:59:49.287 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[098] Begin
# 2025-07-21 02:00:08.429 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[099] Begin
# 2025-07-21 02:00:24.152 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[100] Begin
# 2025-07-21 02:00:45.797 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[101] Begin
# 2025-07-21 02:01:06.191 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[102] Begin
# 2025-07-21 02:01:29.904 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[103] Begin
# 2025-07-21 02:01:49.877 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[104] Begin
# 2025-07-21 02:02:09.222 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[105] Begin
# 2025-07-21 02:02:27.943 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[106] Begin
# 2025-07-21 02:02:46.861 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[107] Begin
# 2025-07-21 02:03:08.299 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[108] Begin
# 2025-07-21 02:03:24.816 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[109] Begin
# 2025-07-21 02:03:41.686 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[110] Begin
# 2025-07-21 02:04:06.229 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[111] Begin
# 2025-07-21 02:04:32.173 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[112] Begin
# 2025-07-21 02:04:53.595 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[113] Begin
# 2025-07-21 02:05:16.114 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[114] Begin
# 2025-07-21 02:05:40.647 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[115] Begin
# 2025-07-21 02:06:00.642 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[116] Begin
# 2025-07-21 02:06:20.570 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[117] Begin
# 2025-07-21 02:06:44.051 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[118] Begin
# 2025-07-21 02:07:00.924 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[119] Begin
# 2025-07-21 02:07:18.512 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[120] Begin
# 2025-07-21 02:07:41.342 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[121] Begin
# 2025-07-21 02:08:05.839 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[122] Begin
# 2025-07-21 02:08:26.111 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[123] Begin
# 2025-07-21 02:08:50.700 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[124] Begin
# 2025-07-21 02:09:12.625 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[125] Begin
# 2025-07-21 02:09:33.835 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[126] Begin
# 2025-07-21 02:09:45.779 | WARNING  | __main__:<module>:46 - ELE[S6006] - ch[127] Begin
# 2025-07-21 02:10:27.245 | WARNING  | __main__:<module>:30 - ELE[4/5]: 	S6072 - D:/Baihm/EISNN/Invivo\S6072_Ver02
# 2025-07-21 02:10:27.246 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[000] Begin
# 2025-07-21 02:10:43.768 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[001] Begin
# 2025-07-21 02:10:54.370 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[002] Begin
# 2025-07-21 02:11:11.963 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[003] Begin
# 2025-07-21 02:11:24.047 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[004] Begin
# 2025-07-21 02:11:44.419 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[005] Begin
# 2025-07-21 02:12:02.647 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[006] Begin
# 2025-07-21 02:12:19.709 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[007] Begin
# 2025-07-21 02:12:37.119 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[008] Begin
# 2025-07-21 02:12:51.542 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[009] Begin
# 2025-07-21 02:13:09.585 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[010] Begin
# 2025-07-21 02:13:31.265 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[011] Begin
# 2025-07-21 02:13:44.398 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[012] Begin
# 2025-07-21 02:14:02.286 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[013] Begin
# 2025-07-21 02:14:25.806 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[014] Begin
# 2025-07-21 02:14:44.824 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[015] Begin
# 2025-07-21 02:14:59.313 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[016] Begin
# 2025-07-21 02:15:16.989 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[017] Begin
# 2025-07-21 02:15:33.376 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[018] Begin
# 2025-07-21 02:15:50.447 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[019] Begin
# 2025-07-21 02:16:08.044 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[020] Begin
# 2025-07-21 02:16:23.860 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[021] Begin
# 2025-07-21 02:16:40.489 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[022] Begin
# 2025-07-21 02:16:57.485 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[023] Begin
# 2025-07-21 02:17:10.881 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[024] Begin
# 2025-07-21 02:17:25.419 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[025] Begin
# 2025-07-21 02:17:46.082 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[026] Begin
# 2025-07-21 02:18:04.494 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[027] Begin
# 2025-07-21 02:18:19.470 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[028] Begin
# 2025-07-21 02:18:38.104 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[029] Begin
# 2025-07-21 02:18:55.853 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[030] Begin
# 2025-07-21 02:19:12.036 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[031] Begin
# 2025-07-21 02:19:27.715 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[032] Begin
# 2025-07-21 02:19:47.093 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[033] Begin
# 2025-07-21 02:20:06.109 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[034] Begin
# 2025-07-21 02:20:21.933 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[035] Begin
# 2025-07-21 02:20:41.843 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[036] Begin
# 2025-07-21 02:21:00.880 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[037] Begin
# 2025-07-21 02:21:16.635 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[038] Begin
# 2025-07-21 02:21:31.707 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[039] Begin
# 2025-07-21 02:21:47.373 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[040] Begin
# 2025-07-21 02:22:05.273 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[041] Begin
# 2025-07-21 02:22:23.506 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[042] Begin
# 2025-07-21 02:22:40.705 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[043] Begin
# 2025-07-21 02:22:53.781 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[044] Begin
# 2025-07-21 02:23:15.632 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[045] Begin
# 2025-07-21 02:23:30.688 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[046] Begin
# 2025-07-21 02:23:47.628 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[047] Begin
# 2025-07-21 02:24:00.780 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[048] Begin
# 2025-07-21 02:24:20.497 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[049] Begin
# 2025-07-21 02:24:34.985 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[050] Begin
# 2025-07-21 02:24:53.802 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[051] Begin
# 2025-07-21 02:25:11.390 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[052] Begin
# 2025-07-21 02:25:28.913 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[053] Begin
# 2025-07-21 02:25:44.540 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[054] Begin
# 2025-07-21 02:26:05.974 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[055] Begin
# 2025-07-21 02:26:14.688 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[056] Begin
# 2025-07-21 02:26:33.695 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[057] Begin
# 2025-07-21 02:26:52.514 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[058] Begin
# 2025-07-21 02:27:08.599 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[059] Begin
# 2025-07-21 02:27:25.657 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[060] Begin
# 2025-07-21 02:27:40.326 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[061] Begin
# 2025-07-21 02:27:55.361 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[062] Begin
# 2025-07-21 02:28:11.200 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[063] Begin
# 2025-07-21 02:28:25.601 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[064] Begin
# 2025-07-21 02:28:42.195 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[065] Begin
# 2025-07-21 02:28:56.574 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[066] Begin
# 2025-07-21 02:29:13.439 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[067] Begin
# 2025-07-21 02:29:30.859 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[068] Begin
# 2025-07-21 02:29:48.760 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[069] Begin
# 2025-07-21 02:30:03.156 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[070] Begin
# 2025-07-21 02:30:17.525 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[071] Begin
# 2025-07-21 02:30:33.216 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[072] Begin
# 2025-07-21 02:30:52.181 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[073] Begin
# 2025-07-21 02:31:09.755 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[074] Begin
# 2025-07-21 02:31:23.008 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[075] Begin
# 2025-07-21 02:31:38.589 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[076] Begin
# 2025-07-21 02:31:53.761 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[077] Begin
# 2025-07-21 02:32:08.023 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[078] Begin
# 2025-07-21 02:32:31.661 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[079] Begin
# 2025-07-21 02:32:44.810 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[080] Begin
# 2025-07-21 02:33:02.506 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[081] Begin
# 2025-07-21 02:33:14.345 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[082] Begin
# 2025-07-21 02:33:33.113 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[083] Begin
# 2025-07-21 02:33:50.125 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[084] Begin
# 2025-07-21 02:34:03.594 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[085] Begin
# 2025-07-21 02:34:18.382 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[086] Begin
# 2025-07-21 02:34:33.048 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[087] Begin
# 2025-07-21 02:34:50.091 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[088] Begin
# 2025-07-21 02:35:03.398 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[089] Begin
# 2025-07-21 02:35:20.138 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[090] Begin
# 2025-07-21 02:35:33.382 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[091] Begin
# 2025-07-21 02:35:54.112 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[092] Begin
# 2025-07-21 02:36:04.311 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[093] Begin
# 2025-07-21 02:36:20.892 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[094] Begin
# 2025-07-21 02:36:34.130 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[095] Begin
# 2025-07-21 02:36:51.501 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[096] Begin
# 2025-07-21 02:37:04.425 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[097] Begin
# 2025-07-21 02:37:17.115 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[098] Begin
# 2025-07-21 02:37:33.459 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[099] Begin
# 2025-07-21 02:37:49.282 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[100] Begin
# 2025-07-21 02:37:59.790 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[101] Begin
# 2025-07-21 02:38:14.294 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[102] Begin
# 2025-07-21 02:38:35.970 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[103] Begin
# 2025-07-21 02:38:54.957 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[104] Begin
# 2025-07-21 02:39:14.079 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[105] Begin
# 2025-07-21 02:39:24.764 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[106] Begin
# 2025-07-21 02:39:36.817 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[107] Begin
# 2025-07-21 02:39:52.508 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[108] Begin
# 2025-07-21 02:40:08.119 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[109] Begin
# 2025-07-21 02:40:24.475 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[110] Begin
# 2025-07-21 02:40:43.539 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[111] Begin
# 2025-07-21 02:40:58.078 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[112] Begin
# 2025-07-21 02:41:18.077 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[113] Begin
# 2025-07-21 02:41:28.135 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[114] Begin
# 2025-07-21 02:41:47.125 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[115] Begin
# 2025-07-21 02:41:58.939 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[116] Begin
# 2025-07-21 02:42:14.591 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[117] Begin
# 2025-07-21 02:42:27.541 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[118] Begin
# 2025-07-21 02:42:42.767 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[119] Begin
# 2025-07-21 02:42:57.555 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[120] Begin
# 2025-07-21 02:43:10.938 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[121] Begin
# 2025-07-21 02:43:26.628 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[122] Begin
# 2025-07-21 02:43:41.187 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[123] Begin
# 2025-07-21 02:43:54.208 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[124] Begin
# 2025-07-21 02:44:17.214 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[125] Begin
# 2025-07-21 02:44:32.894 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[126] Begin
# 2025-07-21 02:44:49.709 | WARNING  | __main__:<module>:46 - ELE[S6072] - ch[127] Begin
# 2025-07-21 02:45:29.711 | WARNING  | __main__:<module>:30 - ELE[5/5]: 	S6106 - D:/Baihm/EISNN/Invivo\S6106_Ver02
# 2025-07-21 02:45:29.712 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[000] Begin
# 2025-07-21 02:45:51.443 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[001] Begin
# 2025-07-21 02:46:13.699 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[002] Begin
# 2025-07-21 02:46:37.719 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[003] Begin
# 2025-07-21 02:46:56.416 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[004] Begin
# 2025-07-21 02:47:18.300 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[005] Begin
# 2025-07-21 02:47:40.027 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[006] Begin
# 2025-07-21 02:48:03.844 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[007] Begin
# 2025-07-21 02:48:26.680 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[008] Begin
# 2025-07-21 02:48:46.566 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[009] Begin
# 2025-07-21 02:49:08.336 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[010] Begin
# 2025-07-21 02:49:32.315 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[011] Begin
# 2025-07-21 02:49:57.044 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[012] Begin
# 2025-07-21 02:50:24.278 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[013] Begin
# 2025-07-21 02:50:44.825 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[014] Begin
# 2025-07-21 02:51:02.707 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[015] Begin
# 2025-07-21 02:51:21.834 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[016] Begin
# 2025-07-21 02:51:40.744 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[017] Begin
# 2025-07-21 02:52:00.969 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[018] Begin
# 2025-07-21 02:52:17.829 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[019] Begin
# 2025-07-21 02:52:35.257 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[020] Begin
# 2025-07-21 02:53:00.976 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[021] Begin
# 2025-07-21 02:53:20.945 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[022] Begin
# 2025-07-21 02:53:44.646 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[023] Begin
# 2025-07-21 02:54:05.548 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[024] Begin
# 2025-07-21 02:54:28.745 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[025] Begin
# 2025-07-21 02:54:48.819 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[026] Begin
# 2025-07-21 02:55:09.397 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[027] Begin
# 2025-07-21 02:55:29.580 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[028] Begin
# 2025-07-21 02:55:45.684 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[029] Begin
# 2025-07-21 02:56:08.787 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[030] Begin
# 2025-07-21 02:56:25.042 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[031] Begin
# 2025-07-21 02:56:46.485 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[032] Begin
# 2025-07-21 02:57:03.488 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[033] Begin
# 2025-07-21 02:57:25.484 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[034] Begin
# 2025-07-21 02:57:48.885 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[035] Begin
# 2025-07-21 02:58:07.633 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[036] Begin
# 2025-07-21 02:58:24.613 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[037] Begin
# 2025-07-21 02:58:40.234 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[038] Begin
# 2025-07-21 02:59:06.687 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[039] Begin
# 2025-07-21 02:59:26.013 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[040] Begin
# 2025-07-21 02:59:48.078 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[041] Begin
# 2025-07-21 03:00:08.997 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[042] Begin
# 2025-07-21 03:00:31.794 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[043] Begin
# 2025-07-21 03:00:54.067 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[044] Begin
# 2025-07-21 03:01:12.675 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[045] Begin
# 2025-07-21 03:01:34.959 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[046] Begin
# 2025-07-21 03:01:58.873 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[047] Begin
# 2025-07-21 03:02:20.200 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[048] Begin
# 2025-07-21 03:02:40.479 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[049] Begin
# 2025-07-21 03:03:00.706 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[050] Begin
# 2025-07-21 03:03:31.389 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[051] Begin
# 2025-07-21 03:03:51.791 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[052] Begin
# 2025-07-21 03:04:10.599 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[053] Begin
# 2025-07-21 03:04:33.950 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[054] Begin
# 2025-07-21 03:04:56.925 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[055] Begin
# 2025-07-21 03:05:17.034 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[056] Begin
# 2025-07-21 03:05:36.982 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[057] Begin
# 2025-07-21 03:06:03.943 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[058] Begin
# 2025-07-21 03:06:22.314 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[059] Begin
# 2025-07-21 03:06:43.412 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[060] Begin
# 2025-07-21 03:07:07.692 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[061] Begin
# 2025-07-21 03:07:32.610 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[062] Begin
# 2025-07-21 03:07:50.297 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[063] Begin
# 2025-07-21 03:08:14.959 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[064] Begin
# 2025-07-21 03:08:38.618 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[065] Begin
# 2025-07-21 03:08:59.151 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[066] Begin
# 2025-07-21 03:09:25.660 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[067] Begin
# 2025-07-21 03:09:45.721 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[068] Begin
# 2025-07-21 03:10:10.204 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[069] Begin
# 2025-07-21 03:10:34.121 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[070] Begin
# 2025-07-21 03:10:56.739 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[071] Begin
# 2025-07-21 03:11:15.678 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[072] Begin
# 2025-07-21 03:11:36.342 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[073] Begin
# 2025-07-21 03:12:00.009 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[074] Begin
# 2025-07-21 03:12:25.745 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[075] Begin
# 2025-07-21 03:12:43.420 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[076] Begin
# 2025-07-21 03:13:04.419 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[077] Begin
# 2025-07-21 03:13:27.631 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[078] Begin
# 2025-07-21 03:13:50.816 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[079] Begin
# 2025-07-21 03:14:14.142 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[080] Begin
# 2025-07-21 03:14:34.271 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[081] Begin
# 2025-07-21 03:14:57.602 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[082] Begin
# 2025-07-21 03:15:13.464 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[083] Begin
# 2025-07-21 03:15:34.882 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[084] Begin
# 2025-07-21 03:16:00.620 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[085] Begin
# 2025-07-21 03:16:20.699 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[086] Begin
# 2025-07-21 03:16:38.245 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[087] Begin
# 2025-07-21 03:16:59.673 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[088] Begin
# 2025-07-21 03:17:16.210 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[089] Begin
# 2025-07-21 03:17:37.894 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[090] Begin
# 2025-07-21 03:18:02.658 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[091] Begin
# 2025-07-21 03:18:24.832 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[092] Begin
# 2025-07-21 03:18:40.665 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[093] Begin
# 2025-07-21 03:19:04.754 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[094] Begin
# 2025-07-21 03:19:28.672 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[095] Begin
# 2025-07-21 03:19:48.723 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[096] Begin
# 2025-07-21 03:20:07.380 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[097] Begin
# 2025-07-21 03:20:26.622 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[098] Begin
# 2025-07-21 03:20:46.506 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[099] Begin
# 2025-07-21 03:21:02.530 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[100] Begin
# 2025-07-21 03:21:22.324 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[101] Begin
# 2025-07-21 03:21:43.936 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[102] Begin
# 2025-07-21 03:22:05.236 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[103] Begin
# 2025-07-21 03:22:26.603 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[104] Begin
# 2025-07-21 03:22:50.047 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[105] Begin
# 2025-07-21 03:23:11.383 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[106] Begin
# 2025-07-21 03:23:30.063 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[107] Begin
# 2025-07-21 03:23:54.466 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[108] Begin
# 2025-07-21 03:24:19.133 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[109] Begin
# 2025-07-21 03:24:42.146 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[110] Begin
# 2025-07-21 03:25:08.464 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[111] Begin
# 2025-07-21 03:25:30.997 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[112] Begin
# 2025-07-21 03:25:52.557 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[113] Begin
# 2025-07-21 03:26:14.554 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[114] Begin
# 2025-07-21 03:26:35.996 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[115] Begin
# 2025-07-21 03:26:51.804 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[116] Begin
# 2025-07-21 03:27:12.348 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[117] Begin
# 2025-07-21 03:27:31.104 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[118] Begin
# 2025-07-21 03:27:47.615 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[119] Begin
# 2025-07-21 03:28:10.224 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[120] Begin
# 2025-07-21 03:28:31.508 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[121] Begin
# 2025-07-21 03:28:55.957 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[122] Begin
# 2025-07-21 03:29:16.220 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[123] Begin
# 2025-07-21 03:29:31.994 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[124] Begin
# 2025-07-21 03:29:55.130 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[125] Begin
# 2025-07-21 03:30:15.434 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[126] Begin
# 2025-07-21 03:30:39.500 | WARNING  | __main__:<module>:46 - ELE[S6106] - ch[127] Begin

# %%
# rootPath = "D:/Baihm/EISNN/Archive/"
# ele_list = SearchELE(rootPath)
# DATASET_SUFFIX = "Outlier_Ver04"

# rootPath = "D:/Baihm/EISNN/Archive_New/"
# ele_list = SearchELE(rootPath)
# DATASET_SUFFIX = "Outlier_Ver04"

rootPath = "D:/Baihm/EISNN/Invivo/"
ele_list = SearchELE(rootPath, re.compile(r"(.+?)_Ver02"))
DATASET_SUFFIX = "Outlier_Ver04"


n_ele = len(ele_list)
logger.info(f"Search in {rootPath} and find {n_ele:03d} electrodes")

# %%
# freq_list = np.linspace(1000,5000-1,101,dtype=int, endpoint=True)
# freq_list = np.linspace(0,5000-1,101,dtype=int, endpoint=True)
# freq_list = freq_list[1:]

DRT_SUFFIX = f"{DATASET_SUFFIX}_DRTLoe_Ver02"
SAVE_FLAG = True
FORCE_FLAG = False

# %%
RUN_FLAG = True
if RUN_FLAG:

    REALFLAG = True
    n_batch = 100
    n_point = 100
    idx_base = 1000
    


    for i in range(n_ele):
    # for i in range(0,1):
        # logger.info(f"ELE Begin: {ele_list[i][0]}")
        fd_pt = os.path.join(ele_list[i][0], DATASET_SUFFIX, f"{ele_list[i][1]}_{DATASET_SUFFIX}.pt")
        if not os.path.exists(fd_pt):
            logger.warning(f"{fd_pt} does not exist")
            continue
        
        data_pt = torch.load(fd_pt)
        _meta_group = data_pt["meta_group"]
        _data_group = data_pt["data_group"]


        ele_id  = _meta_group["ele_id"]
        elePath = _meta_group["elePath"]
        n_ch = _meta_group["n_ch"]      
        x_day_full = _meta_group["TimeSpan"]


        logger.warning(f"ELE[{i+1}/{n_ele}]: \t{ele_id} - {elePath}")


        # Storage path
        save_dir = f"{elePath}/{DRT_SUFFIX}/"
        pt_file_name = f"{ele_id}_{DRT_SUFFIX}.pt"
        os.makedirs(save_dir, exist_ok=True)
        if os.path.exists(os.path.join(save_dir, pt_file_name)):
            logger.warning(f"FileAlreadyExistsWarning: {ele_id} - {pt_file_name} already exists.")
            if SAVE_FLAG and not FORCE_FLAG:
                continue


        for j in _data_group['Channels']:
            try:
            # if 1:
                logger.warning(f"ELE[{ele_id}] - ch[{j:03d}] Begin") 
                channel_group_raw = _data_group[j]


                chData          =   channel_group_raw['chData']         
                eis_seq         =   channel_group_raw['eis_seq']        
                # eis_cluster     =   channel_group_raw['eis_cluster']    
                # eis_anomaly     =   channel_group_raw['eis_anomaly']    
                # leaf_anomaly    =   channel_group_raw['leaf_anomaly']   
                # seq_weird       =   channel_group_raw['seq_weird']      
                # seq_open        =   channel_group_raw['seq_open']       
                # seq_short       =   channel_group_raw['seq_short']      




                if chData.shape[2] != 5000:
                    logger.error(f"ELE[{ele_id}] - ch[{j}] with less than 5000 samples")
                    break
                
                # Run DRT Analysis
                DRTdata_list = []
                EISdata_list = []
                Loess_list = []
                f = chData[0,0,:]
                for k in range(chData.shape[0]):
                    if k in eis_seq:
                        _Z = chData[k,1,:] + 1j*chData[k,2,:]
                        DRTdata, EISdata = DRT_Bootstrap(f, _Z, REALFLAG=REALFLAG, n_batch=n_batch, n_point=n_point, idx_base=idx_base)
                        DRTdata_Loess = DRT_Loess(DRTdata)

                        DRTdata_list.append(DRTdata)
                        EISdata_list.append(EISdata)
                        Loess_list.append(DRTdata_Loess)
                    else:
                        DRTdata_list.append([])
                        EISdata_list.append([])
                        Loess_list.append([])



                # Plot DRT Analysis Results
                fig = plt.figure(figsize=(16, 9), constrained_layout=True)
                fig.suptitle(f"ELE[{ele_id}] - ch[{j:03d}] LFDRT Analysis", fontsize=16, fontweight='bold')
                text_axis=  DRT_Plot_Batch(fig, DRTdata_list, EISdata_list, Loess_list, eis_seq)
                
                font_properties = {
                    'family': 'monospace',  
                    'size': 14,             
                    'weight': 'bold'        
                }

                text = f"EIE  : {ele_id}\nCHID : {j:03d}\nFrom : {x_day_full[0].strftime('%Y-%m-%d')}\nTo   : {x_day_full[-1].strftime('%Y-%m-%d')}"
                text_axis.text(0.2, 0.5, text, fontdict = font_properties, ha='left', va='center')


                # Save Fig
                fig_name = f"DRT_{ele_id}_ch{j:03d}.png"
                
                os.makedirs(save_dir, exist_ok=True) 
                path = os.path.join(save_dir, fig_name)

                fig.savefig(path)
                plt.close('all') 

                # Data Saving
                channel_group_DRT = channel_group_raw
                channel_group_DRT['DRTlist']  = DRTdata_list
                channel_group_DRT['EISlist']  = EISdata_list
                channel_group_DRT['Loesslist']  = Loess_list

                _data_group[j] = channel_group_DRT
                logger.info(f"ELE[{ele_id}] - ch[{j:03d}] Finished")
                
                
            except Exception as e:
                logger.error(f"ELE[{ele_id}] - ch[{j:03d}] Run with error: {e}")
                continue

        
        pt_store = {}
        pt_store["meta_group"] = _meta_group
        pt_store["data_group"] = _data_group
        if SAVE_FLAG:
            torch.save(pt_store, os.path.join(save_dir, pt_file_name))

        del data_pt, _meta_group, _data_group, pt_store
        gc.collect()
# Out:
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\2950697679.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_pt = torch.load(fd_pt)
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.17063e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.62078e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.75679e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.44344e-18): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.34502e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.09235e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=8.96583e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.83441e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.67459e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=9.33493e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=9.56561e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.01064e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.12173e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.36202e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.22551e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.66435e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.21891e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=4.71485e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.12089e-18): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=4.38966e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.61787e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=9.04682e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.16379e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.10279e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.17164e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=4.45094e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.84175e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.54488e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.67611e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.94182e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.01031e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.03743e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.35655e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.72494e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.06251e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.21247e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.97199e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=4.9795e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.87098e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.08786e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.53247e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=9.7427e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.67258e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=8.08315e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.48491e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.81671e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.86361e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.30424e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.25832e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.90697e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.55827e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.22693e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.07597e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=3.98915e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.01384e-18): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.8695e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=4.22612e-18): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=8.21813e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=8.35588e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.1952e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=9.2321e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.10877e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.32639e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.76189e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=5.14262e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.84433e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.56879e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.37623e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.93988e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.82245e-18): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.39558e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.88841e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=9.53045e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.03717e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.07848e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=6.01577e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.09088e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.09371e-16): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=7.14165e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=2.57174e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))
# C:\Users\Baihm\AppData\Local\Temp\4\ipykernel_17712\3811761363.py:102: LinAlgWarning: Ill-conditioned matrix (rcond=1.57128e-17): result may not be accurate.
#   wB = solve(_U, solve(Ek,Bk))

# %%
# fig = plt.figure(figsize=(16, 9), constrained_layout=True)
# fig.suptitle(f"ELE[{ele_id}] - ch[{j:03d}] LFDRT Analysis", fontsize=16, fontweight='bold')
# text_axis=  DRT_Plot_Batch(fig, DRTdata_list, EISdata_list, Loess_list, eis_seq)

# %% [markdown]
# # Viewer

# %%
VIEWER_FLAG = False
if VIEWER_FLAG:
    # ele_id = "02067447"
    # ch_id = 16    # Short with two phased
    # ch_id = 68    # Short Type II

    
    # ele_id = "06017758"
    # ch_id = 10    # Perfect

    
    ele_id = "01037160"
    ch_id = 0    # Short type I

    
    # ele_id = "11057712"
    # # ch_id = 26      # Normal to Short
    # ch_id = 107      # Normal to Short
    
    fd_pt = f"D:/Baihm/EISNN/Archive/{ele_id}_归档\\Outlier_Ver04_DRTLoe_Ver02\\{ele_id}_Outlier_Ver04_DRTLoe_Ver02.pt"

    # Read out
    data_pt = torch.load(fd_pt)
    _data_group = data_pt["data_group"]
    DRTdata_list = _data_group[ch_id]['DRTlist']
    EISdata_list = _data_group[ch_id]['EISlist']
    Loess_list = _data_group[ch_id]['Loesslist']
    
    # Plot
    fig = plt.figure(figsize=(16, 9), constrained_layout=True)
    text_axis = DRT_Plot_Batch(fig, DRTdata_list, EISdata_list, Loess_list, eis_seq)
    # DRT_Plot_Batch_3D(fig, DRTdata[:2], chData[:2,:,:])
