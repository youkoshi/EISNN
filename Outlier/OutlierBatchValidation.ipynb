# %% [markdown]
# # Import

# %%
import os
import re
import gc
import sys
from loguru import logger

import matplotlib.pyplot as plt 

from datetime import datetime

import numpy as np
import torch


sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from HETSFileHelper import gatherCSV, readChannel, EIS_recal_ver02
from Outlier import OutlierDetection
from EISGPR import Interpolation


# %matplotlib qt

# %% [markdown]
# # Filesys

# %%
def SearchELE(rootPath, ele_pattern = re.compile(r"(.+?)_归档")):
    '''==================================================
        Search all electrode directories in the rootPath
        Parameter: 
            rootPath: current search path
            ele_pattern: electrode dir name patten
        Returen:
            ele_list: list of electrode directories
        ==================================================
    '''
    ele_list = []
    for i in os.listdir(rootPath):
        _path = os.path.join(rootPath, i)
        if os.path.isdir(_path):
            match_ele = ele_pattern.match(i)
            if match_ele:
                ele_list.append([_path, match_ele.group(1)])
            else:
                ele_list.extend(SearchELE(_path, ele_pattern))

    return ele_list

# %%
# rootPath = "D:/Baihm/EISNN/Archive/"
# ele_list = SearchELE(rootPath)


rootPath = "D:/Baihm/EISNN/Archive_New/"
ele_list = SearchELE(rootPath)

# rootPath = "D:/Baihm/EISNN/Invivo/"
# ele_list = SearchELE(rootPath, re.compile(r"(.+?)_Ver02"))

n_ele = len(ele_list)
logger.info(f"Search in {rootPath} and find {n_ele:03d} electrodes")
# Out:
# 2025-06-11 15:55:45.221 | INFO     | __main__:<module>:12 - Search in D:/Baihm/EISNN/Archive_New/ and find 187 electrodes

# %% [markdown]
# # Error Processed Statistic

# %%
# 我们观察到，由于我们在最后聚类的时候使用了AP + silhouette_score
# 而silhouette_score 对最低样本数有要求
# 这使得我们会遇到大量报错，之前用try exception跳过了，但是这个可能会导致我们把正常电极误判
# 这里我们打印每个pt文件中，有效电极数和追踪天数
# 如果有效电极数 < 128 - 10 且追踪天数比较多，就认为有问题

DATASET_SUFFIX = "Outlier_Ver04"

n_miss_ele      = 0
n_avaliable_ele = 0


n_all_days      = []



n_few_error     = []
n_open_error    = []
n_nan_error     = []
n_good          = []



for i in range(n_ele):
# for i in range(3):
    # logger.info(f"ELE Begin: {ele_list[i][0]}")
    fd_pt = os.path.join(ele_list[i][0], DATASET_SUFFIX, f"{ele_list[i][1]}_{DATASET_SUFFIX}.pt")
    if not os.path.exists(fd_pt):
        n_miss_ele = n_miss_ele + 1
        logger.warning(f"{fd_pt} does not exist")
        continue
    data_pt = torch.load(fd_pt)
    _meta_group = data_pt["meta_group"]
    _data_group = data_pt["data_group"]


    n_day = _meta_group["n_day"]    
    n_ch = _meta_group["n_ch"]         



    
    ch_few_error = _meta_group["ch_few_error"]  
    ch_open_error = _meta_group["ch_open_error"] 
    ch_nan_error = _meta_group["ch_nan_error"]  
    ch_good = _meta_group["ch_good"]       

    n_avaliable_ele = n_avaliable_ele + len(ch_good)
    n_all_days.append(n_day)
    n_few_error.append(len(ch_few_error))
    n_open_error.append(len(ch_open_error))
    n_nan_error.append(len(ch_nan_error))
    n_good.append(len(ch_good))

    

    logger.info(f"{ele_list[i][1]}[{i:03d}] - [{n_day}]: Error:{len(ch_few_error)} Open:{len(ch_open_error)} Nan:{len(ch_nan_error)} Good:{len(ch_good)}/{n_ch} ")
# Out:
# C:\Users\Baihm\AppData\Local\Temp\5\ipykernel_6760\840094338.py:32: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_pt = torch.load(fd_pt)
# 2025-06-11 15:55:50.191 | INFO     | __main__:<module>:57 - 02027452[000] - [27]: Error:0 Open:41 Nan:0 Good:87/128
# 2025-06-11 15:55:53.225 | INFO     | __main__:<module>:57 - 02027453[001] - [27]: Error:0 Open:46 Nan:0 Good:82/128
# 2025-06-11 15:55:53.240 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\06027742_归档\Outlier_Ver04\06027742_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:53.249 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\09047284_归档\Outlier_Ver04\09047284_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:53.258 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\09047285_归档\Outlier_Ver04\09047285_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:53.261 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\09047286_归档\Outlier_Ver04\09047286_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:54.814 | INFO     | __main__:<module>:57 - 11037287[006] - [9]: Error:17 Open:6 Nan:0 Good:105/128
# 2025-06-11 15:55:54.826 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\11037288_归档\Outlier_Ver04\11037288_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:54.837 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\11037289_归档\Outlier_Ver04\11037289_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:54.842 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\11037721_归档\Outlier_Ver04\11037721_Outlier_Ver04.pt does not exist
# 2025-06-11 15:55:57.630 | INFO     | __main__:<module>:57 - 16057219[010] - [15]: Error:0 Open:6 Nan:0 Good:122/128
# 2025-06-11 15:56:01.687 | INFO     | __main__:<module>:57 - 16057220[011] - [22]: Error:0 Open:9 Nan:0 Good:119/128
# 2025-06-11 15:56:04.309 | INFO     | __main__:<module>:57 - 16057221[012] - [14]: Error:1 Open:6 Nan:0 Good:121/128
# 2025-06-11 15:56:05.312 | INFO     | __main__:<module>:57 - 16067503[013] - [8]: Error:6 Open:43 Nan:0 Good:79/128
# 2025-06-11 15:56:06.062 | INFO     | __main__:<module>:57 - 16067504[014] - [6]: Error:20 Open:28 Nan:0 Good:79/128
# 2025-06-11 15:56:06.705 | INFO     | __main__:<module>:57 - 16067505[015] - [5]: Error:17 Open:34 Nan:0 Good:77/128
# 2025-06-11 15:56:07.749 | INFO     | __main__:<module>:57 - 18017278[016] - [6]: Error:20 Open:0 Nan:0 Good:108/128
# 2025-06-11 15:56:08.432 | INFO     | __main__:<module>:57 - 18017279[017] - [5]: Error:45 Open:2 Nan:0 Good:81/128
# 2025-06-11 15:56:10.587 | INFO     | __main__:<module>:57 - 18017283[018] - [11]: Error:0 Open:3 Nan:0 Good:125/128
# 2025-06-11 15:56:10.606 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\18037272_归档\Outlier_Ver04\18037272_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:10.617 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\18037273_归档\Outlier_Ver04\18037273_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:10.621 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\1月\18037277_归档\Outlier_Ver04\18037277_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:12.229 | INFO     | __main__:<module>:57 - 20017506[022] - [12]: Error:4 Open:34 Nan:0 Good:90/128
# 2025-06-11 15:56:14.000 | INFO     | __main__:<module>:57 - 20017507[023] - [12]: Error:0 Open:33 Nan:0 Good:95/128
# 2025-06-11 15:56:14.482 | INFO     | __main__:<module>:57 - 20017508[024] - [5]: Error:41 Open:29 Nan:0 Good:57/128
# 2025-06-11 15:56:14.496 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\2月\00007471_归档\Outlier_Ver04\00007471_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:16.294 | INFO     | __main__:<module>:57 - 06017750[026] - [13]: Error:1 Open:40 Nan:0 Good:87/128
# 2025-06-11 15:56:17.609 | INFO     | __main__:<module>:57 - 06017751[027] - [11]: Error:0 Open:44 Nan:0 Good:84/128
# 2025-06-11 15:56:18.977 | INFO     | __main__:<module>:57 - 06017752[028] - [11]: Error:4 Open:35 Nan:0 Good:89/128
# 2025-06-11 15:56:20.613 | INFO     | __main__:<module>:57 - 06027743[029] - [12]: Error:0 Open:36 Nan:0 Good:92/128
# 2025-06-11 15:56:22.186 | INFO     | __main__:<module>:57 - 06027744[030] - [13]: Error:0 Open:36 Nan:0 Good:92/128
# 2025-06-11 15:56:23.403 | INFO     | __main__:<module>:57 - 06037735[031] - [11]: Error:1 Open:52 Nan:0 Good:75/128
# 2025-06-11 15:56:24.649 | INFO     | __main__:<module>:57 - 06037736[032] - [11]: Error:6 Open:40 Nan:0 Good:82/128
# 2025-06-11 15:56:26.373 | INFO     | __main__:<module>:57 - 06037737[033] - [11]: Error:0 Open:15 Nan:0 Good:113/128
# 2025-06-11 15:56:27.657 | INFO     | __main__:<module>:57 - 11027701[034] - [12]: Error:0 Open:51 Nan:0 Good:77/128
# 2025-06-11 15:56:28.905 | INFO     | __main__:<module>:57 - 11027702[035] - [12]: Error:4 Open:50 Nan:0 Good:74/128
# 2025-06-11 15:56:30.030 | INFO     | __main__:<module>:57 - 11027707[036] - [11]: Error:1 Open:54 Nan:0 Good:73/128
# 2025-06-11 15:56:30.679 | INFO     | __main__:<module>:57 - 19027671[037] - [5]: Error:43 Open:0 Nan:0 Good:85/128
# 2025-06-11 15:56:31.328 | INFO     | __main__:<module>:57 - 19027672[038] - [5]: Error:36 Open:4 Nan:0 Good:88/128
# 2025-06-11 15:56:32.242 | INFO     | __main__:<module>:57 - 20047596[039] - [16]: Error:16 Open:34 Nan:0 Good:40/128
# 2025-06-11 15:56:33.269 | INFO     | __main__:<module>:57 - 20047597[040] - [17]: Error:25 Open:32 Nan:0 Good:41/128
# 2025-06-11 15:56:33.932 | INFO     | __main__:<module>:57 - 20047598[041] - [16]: Error:11 Open:47 Nan:0 Good:27/128
# 2025-06-11 15:56:33.945 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\02287875_归档\Outlier_Ver04\02287875_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:33.953 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\02287879_归档\Outlier_Ver04\02287879_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:34.596 | INFO     | __main__:<module>:57 - 03020116[044] - [7]: Error:10 Open:58 Nan:0 Good:60/128
# 2025-06-11 15:56:34.608 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\03020124_归档\Outlier_Ver04\03020124_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:34.924 | INFO     | __main__:<module>:57 - 03020135[046] - [5]: Error:83 Open:11 Nan:0 Good:34/128
# 2025-06-11 15:56:34.939 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\03020218_归档\Outlier_Ver04\03020218_Outlier_Ver04.pt does not exist
# 2025-06-11 15:56:35.593 | INFO     | __main__:<module>:57 - 03020219[048] - [6]: Error:2 Open:55 Nan:0 Good:71/128
# 2025-06-11 15:56:36.150 | INFO     | __main__:<module>:57 - 03020320[049] - [6]: Error:6 Open:65 Nan:0 Good:56/128
# 2025-06-11 15:56:37.678 | INFO     | __main__:<module>:57 - 03030101[050] - [13]: Error:0 Open:49 Nan:0 Good:79/128
# 2025-06-11 15:56:38.956 | INFO     | __main__:<module>:57 - 03030201[051] - [11]: Error:8 Open:42 Nan:0 Good:77/128
# 2025-06-11 15:56:40.275 | INFO     | __main__:<module>:57 - 03030203[052] - [11]: Error:1 Open:46 Nan:0 Good:81/128
# 2025-06-11 15:56:41.490 | INFO     | __main__:<module>:57 - 03030301[053] - [11]: Error:5 Open:49 Nan:0 Good:74/128
# 2025-06-11 15:56:42.806 | INFO     | __main__:<module>:57 - 03030302[054] - [11]: Error:0 Open:47 Nan:0 Good:81/128
# 2025-06-11 15:56:43.721 | INFO     | __main__:<module>:57 - 03040101[055] - [9]: Error:1 Open:58 Nan:0 Good:69/128
# 2025-06-11 15:56:44.722 | INFO     | __main__:<module>:57 - 03040102[056] - [9]: Error:0 Open:49 Nan:0 Good:79/128
# 2025-06-11 15:56:45.704 | INFO     | __main__:<module>:57 - 03040201[057] - [9]: Error:2 Open:48 Nan:0 Good:78/128
# 2025-06-11 15:56:46.677 | INFO     | __main__:<module>:57 - 03040202[058] - [9]: Error:0 Open:49 Nan:0 Good:79/128
# 2025-06-11 15:56:47.728 | INFO     | __main__:<module>:57 - 03040203[059] - [9]: Error:0 Open:43 Nan:0 Good:85/128
# 2025-06-11 15:56:48.774 | INFO     | __main__:<module>:57 - 03040301[060] - [9]: Error:0 Open:46 Nan:0 Good:82/128
# 2025-06-11 15:56:49.564 | INFO     | __main__:<module>:57 - 03040302[061] - [9]: Error:20 Open:49 Nan:0 Good:59/128
# 2025-06-11 15:56:50.458 | INFO     | __main__:<module>:57 - 03040303[062] - [9]: Error:8 Open:47 Nan:0 Good:73/128
# 2025-06-11 15:56:51.811 | INFO     | __main__:<module>:57 - 08010102[063] - [12]: Error:0 Open:45 Nan:0 Good:83/128
# 2025-06-11 15:56:53.150 | INFO     | __main__:<module>:57 - 08010103[064] - [12]: Error:0 Open:46 Nan:0 Good:82/128
# 2025-06-11 15:56:54.246 | INFO     | __main__:<module>:57 - 08017685[065] - [10]: Error:15 Open:43 Nan:0 Good:70/128
# 2025-06-11 15:56:55.146 | INFO     | __main__:<module>:57 - 08017686[066] - [9]: Error:13 Open:51 Nan:0 Good:64/128
# 2025-06-11 15:56:56.261 | INFO     | __main__:<module>:57 - 08017690[067] - [10]: Error:20 Open:34 Nan:0 Good:70/128
# 2025-06-11 15:56:57.714 | INFO     | __main__:<module>:57 - 08020202[068] - [11]: Error:2 Open:40 Nan:0 Good:86/128
# 2025-06-11 15:56:58.198 | INFO     | __main__:<module>:57 - 08027698[069] - [6]: Error:38 Open:40 Nan:0 Good:48/128
# 2025-06-11 15:56:58.571 | INFO     | __main__:<module>:57 - 08027700[070] - [5]: Error:59 Open:24 Nan:0 Good:45/128
# 2025-06-11 15:56:59.085 | INFO     | __main__:<module>:57 - 08027811[071] - [6]: Error:50 Open:28 Nan:0 Good:47/128
# 2025-06-11 15:57:00.438 | INFO     | __main__:<module>:57 - 08030303[072] - [11]: Error:0 Open:50 Nan:0 Good:78/128
# 2025-06-11 15:57:02.970 | INFO     | __main__:<module>:57 - 08037812[073] - [21]: Error:0 Open:48 Nan:0 Good:80/128
# 2025-06-11 15:57:03.389 | INFO     | __main__:<module>:57 - 09057824[074] - [6]: Error:78 Open:8 Nan:0 Good:40/128
# 2025-06-11 15:57:03.431 | INFO     | __main__:<module>:57 - 09057826[075] - [5]: Error:81 Open:3 Nan:0 Good:1/128
# 2025-06-11 15:57:04.105 | INFO     | __main__:<module>:57 - 09067805[076] - [7]: Error:43 Open:15 Nan:0 Good:59/128
# 2025-06-11 15:57:04.117 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\10018434_归档\Outlier_Ver04\10018434_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:04.127 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\10028435_归档\Outlier_Ver04\10028435_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:04.134 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\10038436_归档\Outlier_Ver04\10038436_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:04.281 | INFO     | __main__:<module>:57 - 19017783[080] - [5]: Error:110 Open:6 Nan:0 Good:12/128
# 2025-06-11 15:57:04.996 | INFO     | __main__:<module>:57 - 19017784[081] - [5]: Error:42 Open:0 Nan:0 Good:86/128
# 2025-06-11 15:57:05.667 | INFO     | __main__:<module>:57 - 19017785[082] - [5]: Error:50 Open:0 Nan:0 Good:78/128
# 2025-06-11 15:57:06.330 | INFO     | __main__:<module>:57 - 19027673[083] - [5]: Error:47 Open:0 Nan:0 Good:81/128
# 2025-06-11 15:57:07.143 | INFO     | __main__:<module>:57 - 19037628[084] - [5]: Error:20 Open:6 Nan:0 Good:102/128
# 2025-06-11 15:57:07.959 | INFO     | __main__:<module>:57 - 19037629[085] - [5]: Error:32 Open:0 Nan:0 Good:96/128
# 2025-06-11 15:57:08.663 | INFO     | __main__:<module>:57 - 19037633[086] - [5]: Error:39 Open:1 Nan:0 Good:88/128
# 2025-06-11 15:57:08.664 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\25030501_归档\Outlier_Ver04\25030501_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:08.665 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\25030502_归档\Outlier_Ver04\25030502_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:08.665 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\25030503_归档\Outlier_Ver04\25030503_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:08.665 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\3月\划伤\02277845_归档\Outlier_Ver04\02277845_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:09.196 | INFO     | __main__:<module>:57 - 03018905[091] - [5]: Error:54 Open:11 Nan:0 Good:63/128
# 2025-06-11 15:57:10.447 | INFO     | __main__:<module>:57 - 03018906[092] - [7]: Error:17 Open:0 Nan:0 Good:111/128
# 2025-06-11 15:57:11.907 | INFO     | __main__:<module>:57 - 03018907[093] - [7]: Error:0 Open:0 Nan:0 Good:128/128
# 2025-06-11 15:57:13.651 | INFO     | __main__:<module>:57 - 03018908[094] - [9]: Error:0 Open:3 Nan:0 Good:125/128
# 2025-06-11 15:57:14.606 | INFO     | __main__:<module>:57 - 03018909[095] - [5]: Error:8 Open:1 Nan:0 Good:119/128
# 2025-06-11 15:57:16.034 | INFO     | __main__:<module>:57 - 03018910[096] - [7]: Error:2 Open:0 Nan:0 Good:126/128
# 2025-06-11 15:57:16.049 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\03068884_归档\Outlier_Ver04\03068884_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:16.053 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\03068888_归档\Outlier_Ver04\03068888_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:17.018 | INFO     | __main__:<module>:57 - 03068892[099] - [5]: Error:1 Open:0 Nan:0 Good:127/128
# 2025-06-11 15:57:17.034 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\03068965_归档\Outlier_Ver04\03068965_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:17.040 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\03068997_归档\Outlier_Ver04\03068997_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:18.820 | INFO     | __main__:<module>:57 - 03258451[102] - [14]: Error:0 Open:41 Nan:0 Good:87/128
# 2025-06-11 15:57:20.653 | INFO     | __main__:<module>:57 - 03258452[103] - [14]: Error:1 Open:39 Nan:0 Good:88/128
# 2025-06-11 15:57:22.314 | INFO     | __main__:<module>:57 - 03258453[104] - [14]: Error:1 Open:43 Nan:0 Good:84/128
# 2025-06-11 15:57:24.094 | INFO     | __main__:<module>:57 - 03258454[105] - [14]: Error:0 Open:42 Nan:0 Good:85/128
# 2025-06-11 15:57:25.863 | INFO     | __main__:<module>:57 - 03258455[106] - [14]: Error:0 Open:39 Nan:0 Good:89/128
# 2025-06-11 15:57:27.559 | INFO     | __main__:<module>:57 - 03258456[107] - [14]: Error:0 Open:44 Nan:0 Good:84/128
# 2025-06-11 15:57:28.716 | INFO     | __main__:<module>:57 - 04118865[108] - [14]: Error:1 Open:72 Nan:0 Good:55/128
# 2025-06-11 15:57:30.351 | INFO     | __main__:<module>:57 - 04118866[109] - [14]: Error:3 Open:43 Nan:0 Good:82/128
# 2025-06-11 15:57:32.248 | INFO     | __main__:<module>:57 - 04118867[110] - [14]: Error:0 Open:36 Nan:0 Good:92/128
# 2025-06-11 15:57:35.445 | INFO     | __main__:<module>:57 - 06017759[111] - [39]: Error:0 Open:69 Nan:0 Good:59/128
# 2025-06-11 15:57:38.711 | INFO     | __main__:<module>:57 - 08017689[112] - [29]: Error:0 Open:49 Nan:0 Good:79/128
# 2025-06-11 15:57:39.372 | INFO     | __main__:<module>:57 - 08018662[113] - [7]: Error:6 Open:66 Nan:0 Good:56/128
# 2025-06-11 15:57:40.006 | INFO     | __main__:<module>:57 - 08018663[114] - [7]: Error:2 Open:68 Nan:0 Good:58/128
# 2025-06-11 15:57:40.766 | INFO     | __main__:<module>:57 - 08018664[115] - [7]: Error:1 Open:63 Nan:0 Good:64/128
# 2025-06-11 15:57:43.896 | INFO     | __main__:<module>:57 - 08027696[116] - [26]: Error:0 Open:48 Nan:0 Good:80/128
# 2025-06-11 15:57:47.015 | INFO     | __main__:<module>:57 - 08027697[117] - [26]: Error:0 Open:47 Nan:0 Good:81/128
# 2025-06-11 15:57:50.160 | INFO     | __main__:<module>:57 - 08027699[118] - [26]: Error:0 Open:46 Nan:0 Good:82/128
# 2025-06-11 15:57:51.012 | INFO     | __main__:<module>:57 - 08028852[119] - [7]: Error:9 Open:47 Nan:0 Good:72/128
# 2025-06-11 15:57:51.631 | INFO     | __main__:<module>:57 - 08028853[120] - [7]: Error:5 Open:70 Nan:0 Good:53/128
# 2025-06-11 15:57:52.503 | INFO     | __main__:<module>:57 - 08028854[121] - [7]: Error:4 Open:46 Nan:0 Good:78/128
# 2025-06-11 15:57:56.497 | INFO     | __main__:<module>:57 - 08037814[122] - [34]: Error:0 Open:49 Nan:0 Good:79/128
# 2025-06-11 15:57:59.827 | INFO     | __main__:<module>:57 - 08037815[123] - [31]: Error:0 Open:56 Nan:0 Good:72/128
# 2025-06-11 15:57:59.839 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\08058293_归档\Outlier_Ver04\08058293_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:59.848 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\08058295_归档\Outlier_Ver04\08058295_Outlier_Ver04.pt does not exist
# 2025-06-11 15:57:59.855 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\08058298_归档\Outlier_Ver04\08058298_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:02.056 | INFO     | __main__:<module>:57 - 09067803[127] - [16]: Error:6 Open:27 Nan:0 Good:95/128
# 2025-06-11 15:58:03.956 | INFO     | __main__:<module>:57 - 12068259[128] - [10]: Error:1 Open:1 Nan:0 Good:126/128
# 2025-06-11 15:58:07.329 | INFO     | __main__:<module>:57 - 13058215[129] - [28]: Error:0 Open:45 Nan:0 Good:83/128
# 2025-06-11 15:58:07.345 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\16047918_归档\Outlier_Ver04\16047918_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:07.391 | INFO     | __main__:<module>:57 - 16047919[131] - [5]: Error:6 Open:10 Nan:0 Good:1/128
# 2025-06-11 15:58:08.375 | INFO     | __main__:<module>:57 - 18048868[132] - [5]: Error:2 Open:0 Nan:0 Good:126/128
# 2025-06-11 15:58:08.902 | INFO     | __main__:<module>:57 - 18048870[133] - [5]: Error:16 Open:34 Nan:0 Good:65/128
# 2025-06-11 15:58:09.725 | INFO     | __main__:<module>:57 - 18048871[134] - [5]: Error:27 Open:0 Nan:0 Good:101/128
# 2025-06-11 15:58:10.225 | INFO     | __main__:<module>:57 - 19026157[135] - [5]: Error:69 Open:0 Nan:0 Good:59/128
# 2025-06-11 15:58:10.244 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/2025\4月\19026160_归档\Outlier_Ver04\19026160_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:10.824 | INFO     | __main__:<module>:57 - 19026165[137] - [5]: Error:55 Open:0 Nan:0 Good:73/128
# 2025-06-11 15:58:11.168 | INFO     | __main__:<module>:57 - 19026168 [138] - [6]: Error:91 Open:2 Nan:0 Good:32/128
# 2025-06-11 15:58:12.236 | INFO     | __main__:<module>:57 - 19028349[139] - [6]: Error:7 Open:0 Nan:0 Good:113/128
# 2025-06-11 15:58:12.285 | INFO     | __main__:<module>:57 - 19028372[140] - [7]: Error:111 Open:0 Nan:0 Good:1/128
# 2025-06-11 15:58:12.761 | INFO     | __main__:<module>:57 - 19028375[141] - [6]: Error:64 Open:2 Nan:0 Good:50/128
# 2025-06-11 15:58:12.844 | INFO     | __main__:<module>:57 - 19028380[142] - [6]: Error:111 Open:4 Nan:0 Good:4/128
# 2025-06-11 15:58:12.911 | INFO     | __main__:<module>:57 - 22057894[143] - [7]: Error:31 Open:1 Nan:0 Good:3/128
# 2025-06-11 15:58:13.279 | INFO     | __main__:<module>:57 - 22057895[144] - [7]: Error:40 Open:6 Nan:0 Good:32/128
# 2025-06-11 15:58:13.411 | INFO     | __main__:<module>:57 - 24067931[145] - [5]: Error:118 Open:0 Nan:0 Good:10/128
# 2025-06-11 15:58:13.469 | INFO     | __main__:<module>:57 - 24067934[146] - [5]: Error:96 Open:2 Nan:0 Good:1/128
# 2025-06-11 15:58:13.606 | INFO     | __main__:<module>:57 - 24067935[147] - [6]: Error:64 Open:4 Nan:0 Good:9/128
# 2025-06-11 15:58:15.143 | INFO     | __main__:<module>:57 - 27018542[148] - [10]: Error:4 Open:12 Nan:0 Good:112/128
# 2025-06-11 15:58:17.080 | INFO     | __main__:<module>:57 - 27018543[149] - [12]: Error:0 Open:8 Nan:0 Good:120/128
# 2025-06-11 15:58:18.646 | INFO     | __main__:<module>:57 - 27018544[150] - [10]: Error:2 Open:11 Nan:0 Good:115/128
# 2025-06-11 15:58:20.226 | INFO     | __main__:<module>:57 - 27028524[151] - [12]: Error:0 Open:29 Nan:0 Good:99/128
# 2025-06-11 15:58:21.892 | INFO     | __main__:<module>:57 - 27028525[152] - [11]: Error:0 Open:17 Nan:0 Good:111/128
# 2025-06-11 15:58:22.764 | INFO     | __main__:<module>:57 - 27028527[153] - [6]: Error:15 Open:9 Nan:0 Good:103/128
# 2025-06-11 15:58:22.784 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\03048656_归档\Outlier_Ver04\03048656_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:23.959 | INFO     | __main__:<module>:57 - 03048657[155] - [6]: Error:1 Open:1 Nan:0 Good:125/128
# 2025-06-11 15:58:25.036 | INFO     | __main__:<module>:57 - 03048659[156] - [6]: Error:6 Open:4 Nan:0 Good:118/128
# 2025-06-11 15:58:25.037 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\04028546_归档\Outlier_Ver04\04028546_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.037 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\04028558_归档\Outlier_Ver04\04028558_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.038 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\12068258_归档\Outlier_Ver04\12068258_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.038 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\12068259_归档\Outlier_Ver04\12068259_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.039 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\12068260_归档\Outlier_Ver04\12068260_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.039 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\12348870_归档\Outlier_Ver04\12348870_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.039 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\13058215_归档\Outlier_Ver04\13058215_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.051 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\16057937_归档\Outlier_Ver04\16057937_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.060 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\16057939_归档\Outlier_Ver04\16057939_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.062 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\16057942_归档\Outlier_Ver04\16057942_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.093 | INFO     | __main__:<module>:57 - 18058971[167] - [5]: Error:128 Open:0 Nan:0 Good:0/128
# 2025-06-11 15:58:25.108 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\18058972_归档\Outlier_Ver04\18058972_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.118 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\18058973_归档\Outlier_Ver04\18058973_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.131 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\19026157_归档\Outlier_Ver04\19026157_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.133 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\19026160_归档\Outlier_Ver04\19026160_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.135 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\19026165_归档\Outlier_Ver04\19026165_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.136 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\24058552_归档\Outlier_Ver04\24058552_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.138 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\24058559_归档\Outlier_Ver04\24058559_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.148 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\24058792_归档\Outlier_Ver04\24058792_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.166 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\24058793_归档\Outlier_Ver04\24058793_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.177 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\24058794_归档\Outlier_Ver04\24058794_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.258 | INFO     | __main__:<module>:57 - 24068795[178] - [5]: Error:100 Open:0 Nan:0 Good:8/128
# 2025-06-11 15:58:25.476 | INFO     | __main__:<module>:57 - 24068796[179] - [5]: Error:95 Open:0 Nan:0 Good:24/128
# 2025-06-11 15:58:25.581 | INFO     | __main__:<module>:57 - 24068797[180] - [5]: Error:106 Open:1 Nan:0 Good:8/128
# 2025-06-11 15:58:25.582 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\27018542_归档\Outlier_Ver04\27018542_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.582 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\27018543_归档\Outlier_Ver04\27018543_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.583 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\27018544_归档\Outlier_Ver04\27018544_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.583 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\27028524_归档\Outlier_Ver04\27028524_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.583 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\27028525_归档\Outlier_Ver04\27028525_Outlier_Ver04.pt does not exist
# 2025-06-11 15:58:25.584 | WARNING  | __main__:<module>:30 - D:/Baihm/EISNN/Archive_New/bad\27028527_归档\Outlier_Ver04\27028527_Outlier_Ver04.pt does not exist

# %%
n_all_days = np.array(n_all_days)
n_few_error = np.array(n_few_error)
n_open_error = np.array(n_open_error)
n_nan_error = np.array(n_nan_error)
n_good = np.array(n_good)

# %%
cnt_few_error  =  n_few_error  
cnt_open_error =  n_open_error
cnt_nan_error  =  n_nan_error 
cnt_good       =  n_good      
logger.info(f"\n cnt_few_error:{np.sum(cnt_few_error)}\
            \ncnt_open_error:{np.sum(cnt_open_error)}\
            \ncnt_nan_error:{np.sum(cnt_nan_error)}\
            \ncnt_good:{np.sum(cnt_good)}\
            \nsum:{np.sum(cnt_few_error)+np.sum(cnt_open_error)+np.sum(cnt_nan_error)+np.sum(cnt_good)}")
# Out:
# 2025-06-11 15:59:00.567 | INFO     | __main__:<module>:5 -
#  cnt_few_error:2691
# cnt_open_error:3557
# cnt_nan_error:0
# cnt_good:9644
# sum:15892

# %%
cnt_few_error  =  n_all_days * n_few_error  
cnt_open_error =  n_all_days * n_open_error
cnt_nan_error  =  n_all_days * n_nan_error 
cnt_good       =  n_all_days * n_good      
logger.info(f"\n cnt_few_error:{np.sum(cnt_few_error)}\
            \ncnt_open_error:{np.sum(cnt_open_error)}\
            \ncnt_nan_error:{np.sum(cnt_nan_error)}\
            \ncnt_good:{np.sum(cnt_good)}\
            \nsum:{np.sum(cnt_few_error)+np.sum(cnt_open_error)+np.sum(cnt_nan_error)+np.sum(cnt_good)}")
# Out:
# 2025-06-11 15:59:12.817 | INFO     | __main__:<module>:5 -
#  cnt_few_error:16020
# cnt_open_error:46380
# cnt_nan_error:0
# cnt_good:105836
# sum:168236

# %%
print(n_ele,n_miss_ele)
# Out:
# 218 65

# %%
import matplotlib.pyplot as plt
import numpy as np

# 设置数据
labels = ['In vitro', 'In vivo']
categories = ['Good', 'Abnormal', 'Open']
main_colors = ['green', 'orange', 'red']
light_colors = ['lightgreen', 'khaki', 'lightcoral']

# 主数据集（前面给出的）
main_counts = {
    'Good':     [229803, 13707],
    'Abnormal':     [30585, 245],
    'Open': [102196, 0],
}

# 对比数据集（新提供的）
comp_counts = {
    'Good':     [21878, 719],
    'Abnormal':     [5013, 49],
    'Open': [8432, 0],
}

# 计算总和用于比例
main_totals = [sum([main_counts[cat][i] for cat in categories]) for i in range(2)]
comp_totals = [sum([comp_counts[cat][i] for cat in categories]) for i in range(2)]

# 计算比例
main_ratios = {cat: [main_counts[cat][i] / main_totals[i] for i in range(2)] for cat in categories}
comp_ratios = {cat: [comp_counts[cat][i] / comp_totals[i] for i in range(2)] for cat in categories}

# 准备绘图
x = np.arange(len(labels))  # [0, 1] for 'in vitro', 'in vivo'
width = 0.2  # 每根柱子宽度

fig, ax = plt.subplots(figsize=(4, 6))

width_weight = 0.4

for i, cat in enumerate(categories):
    # 左右偏移
    main_pos = x + ((i-1) * width)  # 主数据左边三根柱子
    comp_pos = main_pos + width_weight*width       # 对比数据右边三根柱子

    # 主数据柱状图
    main_bars = ax.bar(
        main_pos, main_ratios[cat], width=width_weight*width, color=main_colors[i], label=f"#{cat} (samples)", zorder=3
    )
    comp_bars = ax.bar(
        comp_pos, comp_ratios[cat], width=width_weight*width, color=light_colors[i], label=f"#{cat} (electrodes)", zorder=3
    )

    # 添加文字标签（主数据）
    for j in range(len(main_bars)):
        height = main_bars[j].get_height()
        if height <= 1.0:
            ax.text(
                main_bars[j].get_x() + main_bars[j].get_width()/2 , height + 0.02,
                f"{main_counts[cat][j]}",
                ha='center', va='bottom', fontsize=12, rotation=45, fontweight='bold'
            )
    # 添加文字标签（对比数据）
    for j in range(len(comp_bars)):
        height = comp_bars[j].get_height()
        if height <= 1.0:
            ax.text(
                comp_bars[j].get_x() + comp_bars[j].get_width()/2, height + 0.02,
                f"{comp_counts[cat][j]}",
                ha='center', va='bottom', fontsize=12, rotation=45, fontweight='bold'
            )



# 图例、坐标轴、网格等美化
ax.set_ylim(0, 1.2)
ax.set_ylabel("Percentage", fontsize=16, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=16, fontweight='bold')
ax.set_yticks(np.linspace(0, 1.0, 11))
ax.set_yticklabels([f"{int(t * 100)}%" for t in np.linspace(0, 1.0, 11)])

ax.legend(title="Category", fontsize=10, loc=(2))
ax.grid(True, axis='y', linestyle='--', alpha=0.5, zorder=0)

plt.title(f"EIS Data Summary")
plt.tight_layout()
plt.show()
