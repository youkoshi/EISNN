# %%
import os

# %%
# rootPath = "D:\Baihm\EISNN\Archive_New"
rootPath = "D:\Baihm\EISNN\Archive"

def delete_ehd_files(directory):
    deleted_count = 0
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.ehd'):
                file_path = os.path.join(root, file)
                try:
                    os.remove(file_path)
                    print(f"已删除: {file_path}")
                    deleted_count += 1
                except Exception as e:
                    print(f"删除失败: {file_path}，原因: {e}")
    if deleted_count == 0:
        print("没有找到 .ehd 文件。")
    else:
        print(f"总共删除了 {deleted_count} 个 .ehd 文件。")

# 示例调用
delete_ehd_files(rootPath)
# Out:
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_19-EIS20mV.bin-ch031.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_24-EIS20mV.bin-ch030.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_29-EIS20mV.bin-ch029.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_34-EIS20mV.bin-ch028.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_38-EIS20mV.bin-ch027.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_43-EIS20mV.bin-ch026.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_47-EIS20mV.bin-ch025.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_52-EIS20mV.bin-ch024.ehd
# 已删除: D:\Baihm\EISNN\Archive\09231407_归档\09231407_20241104_01\1\20241104_15_11_57-EIS20mV.bin-ch023.ehd
# ...
